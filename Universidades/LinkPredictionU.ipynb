# %%
import networkx as nx
import numpy as np
import pandas as pd
import json

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier

from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

from tqdm import tqdm

# %%
#Definiendo varias metricas para link prediction
def commonNeighbors(G,source,target):
  adj = dict(G.adj[source])
  adj2 = dict(G.adj[target])
  commonNeighbors = set(adj.keys()) & set(adj2.keys())
  return commonNeighbors

def jaccardCoeff(G,source,target):
  adj = dict(G.adj[source])
  adj2 = dict(G.adj[target])
  unionNeighbors = set(adj.keys()) | set(adj2.keys())
  commonNeighbors = set(adj.keys()) & set(adj2.keys())
  return len(commonNeighbors)/len(unionNeighbors)

def adamicAdar(G,source,target):
  cn = commonNeighbors(G,source,target)
  coeff = 0
  for neighbor in cn:
    if len(dict(G.adj[neighbor]).keys()) >1:
      coeff += 1/np.log(len(dict(G.adj[neighbor]).keys()))
  return coeff

def similarity(G,source,target):
    adj = dict(G.adj[source])
    adj2 = dict(G.adj[target])
    y=0.5
    val = 0
    for a in set(adj.keys()):
        for b in set(adj2.keys()):
            if a==b:
                val+= 1
            else:
                val+= similarity(G,a,b)
    return val/(len(adj.keys())*len(adj2.keys()))

def commonKeywords(nodes_df,source,target):
  keywords1 = list(nodes_df[nodes_df["ID"]==source]["KeywordsB2018"])
  keywords1 = set(str(keywords1[0]).split(","))
  keywords2 = list(nodes_df[nodes_df["ID"]==target]["KeywordsB2018"])
  keywords2 = set(str(keywords2[0]).split(","))
  common = keywords1 & keywords2
  return len(common)

#Contador binario
def contador(l):
    acarreo =True
    for i in range(len(l)):
        if(acarreo):
            l[i] = not(l[i])
            acarreo = l[i]
    return l

# %%
universidades = ['ESPOL', 'PUCC', 'PUCP', 'TecMonterrey', 'UCNSA', 'UCV',
                 'Udelar', 'UM', 'UNAM', 'Unicamp', 'Universidad de Antioquia', 
                 'Universidad de Chile', 'Universidad de Los Andes', 
                 'Universidad Nacional de la Asuncion', 'Universidad Torcuato Di Tella', 
                 'UPB', 'UPCH', 'USB', 'USFQ', 'USP']
predictionsDic = {}
cont=0
for univ in tqdm(universidades,desc='Universidades'):
  archivo_edges = "data/componente_gigante/coauthors-edgesCG-"+univ+".csv"
  archivo_nodes = "data/componente_gigante/coauthors-nodesCG-"+univ+".csv"
  coau_df = pd.read_csv(archivo_edges,delimiter=";")
  nodos_df = pd.read_csv(archivo_nodes,delimiter=";")
  G = nx.from_pandas_edgelist(coau_df,"Source","Target",['Weight','Year'],create_using=nx.Graph())
  nodos = list(G.nodes)
  #Obteniendo dataframe de pares de nodos que no tienen coneccion

  adj_G = nx.to_numpy_matrix(G, nodelist = nodos)
  all_unconnected_pairs = []

  offset = 0
  for i in range(adj_G.shape[0]):
    for j in range(offset,adj_G.shape[1]):
      if i != j:
            if adj_G[i,j] == 0:
              all_unconnected_pairs.append((nodos[i],nodos[j]))

    offset = offset + 1

  node_1_unlinked = [i[0] for i in all_unconnected_pairs]
  node_2_unlinked = [i[1] for i in all_unconnected_pairs]

  #Creando dataframe para almacenar a los pares de nodos no conectados que se recogieron
  data = pd.DataFrame({'Source':node_1_unlinked,'Target':node_2_unlinked})
  data['Weight'] = 0
  data['link'] = 0

  indices = range(len(data['Source']))
  #Separando el dataframe en datos para train y para test
  #(se busca un numero no muy grande de datos de pares que no tienen coneccion en los datos para entrenar, para
  #evitar que los datos de entrenamiento esten desbalanceados)

  if len(indices) > len(coau_df['Source'])*5:
    _, indices = train_test_split(indices,test_size=0.15,random_state=73)
  removeIn, noRemoveIn = train_test_split(indices,test_size=0.25,random_state=32)

  test= data.copy()
  test = test.loc[noRemoveIn]

  data = data.loc[removeIn]

  #Trabajando con los pares de nodos que si estan conectados

  #Obteniendo lista de los links que se pueden borrar (que no eliminan nodos, o dividen al grafo en mas de una componente) y que
  #estan despues del año establecido

  year = 2018
  initial_node_count = len(G.nodes)

  coau_df_temp = coau_df.copy()

  omissible_links_index = []
  for i in tqdm(coau_df.index.values):
      if G.adj[coau_df.values[i,0]][coau_df.values[i,1]]['Year']>=year:
          # Eliminar una arista y construir un nuevo grafo sin esa unica arista
          G_temp = nx.from_pandas_edgelist(coau_df_temp.drop(index=i), "Source", "Target",["Weight"], create_using=nx.Graph())

          # Verificando que al eliminar este par, no parte el grafo, y que el numero de nodos siga siendo el mismo

          if (nx.number_connected_components(G_temp) == 1) and (len(G_temp.nodes) == initial_node_count):
              omissible_links_index.append(i)
              coau_df_temp = coau_df_temp.drop(i)

  #creando dataframe de edges que se pueden remover

  coau_df_temp2 = coau_df.copy()
  coau_df_temp2["link"]=1

  #Separando dataframe en datos para train y test

  testlinks = coau_df_temp2.loc[omissible_links_index]
  coau_df_temp = coau_df_temp2.drop(index=omissible_links_index)

  data = data.append(coau_df_temp[['Source', 'Target', 'link','Weight']], ignore_index=True)
  data["Weight"] = data["Weight"].astype('int64')

  test = test.append(testlinks[['Source', 'Target', 'link','Weight']], ignore_index=True)


  #Creando nuevo grafo sin los links eliminados
  G_data = nx.from_pandas_edgelist(coau_df_temp, "Source", "Target",["Weight"], create_using=nx.Graph())

  #SacandoFeatures:
  Xtrain =[]
  Ytrain =[]
  for i in data.values:
      Xtrain.append([len(commonNeighbors(G_data,i[0],i[1])),jaccardCoeff(G_data,i[0],i[1]),
                     adamicAdar(G_data,i[0],i[1]),commonKeywords(nodos_df,i[0],i[1])])
      Ytrain.append(i[3])
  Xtrain = np.array(Xtrain)
  Ytrain = np.array(Ytrain)

  Xtest = []
  Ytest = []
  for i in test.values:
      Xtest.append([len(commonNeighbors(G_data,i[0],i[1])),jaccardCoeff(G_data,i[0],i[1]),
                    adamicAdar(G_data,i[0],i[1]),commonKeywords(nodos_df,i[0],i[1])])
      Ytest.append(i[3])

  Xtest = np.array(Xtest)
  Ytest = np.array(Ytest)

  #Prediciendo
  lista = ['CommonNeighbors',"JaccardCoeff","AdamicAdar","CommonKeywords"]
  lista = np.array(lista)
  l = [True]*len(lista)
  predictionsDic[univ] ={}
  for i in range(2**len(lista)-1):
    
    lr = LogisticRegression(class_weight="balanced")
    lr.fit(Xtrain[:,l], Ytrain)

    predictions = lr.predict(Xtest[:,l])
    t = "-".join(lista[l])
    
    predictionsDic[univ][t] = {
            'regresionLogistica':{
                'accuracy':accuracy_score(Ytest,predictions),
                'roc_auc':roc_auc_score(Ytest, predictions),
                'recall':recall_score(Ytest,predictions),
                'precision':precision_score(Ytest,predictions)
                }
            }
        
                
    clf = SVC(gamma='scale')

    clf.fit(Xtrain[:,l], Ytrain)
    predictions = clf.predict(Xtest[:,l])

    predictionsDic[univ][t]['SVC'] = {
        'accuracy':accuracy_score(Ytest,predictions),
        'roc_auc':roc_auc_score(Ytest, predictions),
        'recall':recall_score(Ytest,predictions),
        'precision':precision_score(Ytest,predictions)
    }

    bagging = BaggingClassifier(base_estimator=LogisticRegression(class_weight="balanced"),n_estimators=10, random_state=0).fit(Xtrain[:,l], Ytrain)
    predictions = bagging.predict(Xtest[:,l])

    predictionsDic[univ][t]['Bagging'] = {
        'accuracy':accuracy_score(Ytest,predictions),
        'roc_auc':roc_auc_score(Ytest, predictions),
        'recall':recall_score(Ytest,predictions),
        'precision':precision_score(Ytest,predictions)
    }
    l = contador(l)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#
#  35%|███▍      | 1675/4801 [00:48<01:32, 33.68it/s]
#
#
#
#
#
#
#  35%|███▌      | 1684/4801 [00:48<01:16, 40.58it/s]
#
#
#
#
#
#
#  35%|███▌      | 1690/4801 [00:49<01:17, 40.19it/s]
#
#
#
#
#
#
#  35%|███▌      | 1695/4801 [00:49<01:14, 41.83it/s]
#
#
#
#
#
#
#  35%|███▌      | 1700/4801 [00:49<01:16, 40.38it/s]
#
#
#
#
#
#
#  36%|███▌      | 1705/4801 [00:49<01:48, 28.56it/s]
#
#
#
#
#
#
#  36%|███▌      | 1709/4801 [00:49<01:45, 29.21it/s]
#
#
#
#
#
#
#  36%|███▌      | 1713/4801 [00:49<01:41, 30.54it/s]
#
#
#
#
#
#
#  36%|███▌      | 1718/4801 [00:50<01:33, 32.89it/s]
#
#
#
#
#
#
#  36%|███▌      | 1724/4801 [00:50<01:21, 37.64it/s]
#
#
#
#
#
#
#  36%|███▌      | 1730/4801 [00:50<01:33, 32.96it/s]
#
#
#
#
#
#
#  36%|███▌      | 1735/4801 [00:50<01:27, 34.97it/s]
#
#
#
#
#
#
#  36%|███▋      | 1741/4801 [00:50<01:17, 39.42it/s]
#
#
#
#
#
#
#  36%|███▋      | 1746/4801 [00:50<01:17, 39.43it/s]
#
#
#
#
#
#
#  36%|███▋      | 1751/4801 [00:50<01:19, 38.60it/s]
#
#
#
#
#
#
#  37%|███▋      | 1760/4801 [00:50<01:06, 46.07it/s]
#
#
#
#
#
#
#  37%|███▋      | 1766/4801 [00:51<01:26, 35.06it/s]
#
#
#
#
#
#
#  37%|███▋      | 1771/4801 [00:51<01:24, 35.97it/s]
#
#
#
#
#
#
#  37%|███▋      | 1776/4801 [00:51<01:22, 36.62it/s]
#
#
#
#
#
#
#  37%|███▋      | 1781/4801 [00:51<01:21, 37.15it/s]
#
#
#
#
#
#
#  37%|███▋      | 1786/4801 [00:51<01:19, 37.73it/s]
#
#
#
#
#
#
#  37%|███▋      | 1791/4801 [00:52<01:49, 27.47it/s]
#
#
#
#
#
#
#  37%|███▋      | 1796/4801 [00:52<01:36, 31.11it/s]
#
#
#
#
#
#
#  38%|███▊      | 1801/4801 [00:52<01:25, 35.00it/s]
#
#
#
#
#
#
#  38%|███▊      | 1806/4801 [00:52<01:22, 36.27it/s]
#
#
#
#
#
#
#  38%|███▊      | 1816/4801 [00:52<01:07, 44.44it/s]
#
#
#
#
#
#
#  38%|███▊      | 1824/4801 [00:52<00:58, 50.78it/s]
#
#
#
#
#
#
#  38%|███▊      | 1831/4801 [00:52<01:23, 35.56it/s]
#
#
#
#
#
#
#  38%|███▊      | 1836/4801 [00:53<01:21, 36.35it/s]
#
#
#
#
#
#
#  38%|███▊      | 1841/4801 [00:53<01:19, 37.41it/s]
#
#
#
#
#
#
#  38%|███▊      | 1846/4801 [00:53<01:17, 38.20it/s]
#
#
#
#
#
#
#  39%|███▊      | 1851/4801 [00:53<01:43, 28.61it/s]
#
#
#
#
#
#
#  39%|███▊      | 1855/4801 [00:53<01:34, 31.19it/s]
#
#
#
#
#
#
#  39%|███▊      | 1859/4801 [00:53<01:28, 33.12it/s]
#
#
#
#
#
#
#  39%|███▉      | 1863/4801 [00:53<01:27, 33.50it/s]
#
#
#
#
#
#
#  39%|███▉      | 1867/4801 [00:53<01:25, 34.23it/s]
#
#
#
#
#
#
#  39%|███▉      | 1879/4801 [00:54<01:07, 43.02it/s]
#
#
#
#
#
#
#  39%|███▉      | 1885/4801 [00:54<01:34, 30.86it/s]
#
#
#
#
#
#
#  39%|███▉      | 1890/4801 [00:54<01:29, 32.69it/s]
#
#
#
#
#
#
#  39%|███▉      | 1895/4801 [00:54<01:20, 36.02it/s]
#
#
#
#
#
#
#  40%|███▉      | 1900/4801 [00:54<01:15, 38.32it/s]
#
#
#
#
#
#
#  40%|███▉      | 1905/4801 [00:54<01:16, 37.84it/s]
#
#
#
#
#
#
#  40%|███▉      | 1910/4801 [00:55<01:42, 28.29it/s]
#
#
#
#
#
#
#  42%|████▏     | 2011/4801 [00:55<01:09, 39.93it/s]
#
#
#
#
#
#
#  45%|████▍     | 2137/4801 [00:55<00:47, 56.28it/s]
#
#
#
#
#
#
#  47%|████▋     | 2264/4801 [00:55<00:32, 78.90it/s]
#
#
#
#
#
#
#  50%|████▉     | 2390/4801 [00:55<00:21, 109.76it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2522/4801 [00:55<00:15, 151.38it/s]
#
#
#
#
#
#
#  55%|█████▌    | 2654/4801 [00:55<00:10, 206.11it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2769/4801 [00:55<00:07, 273.30it/s]
#
#
#
#
#
#
#  60%|██████    | 2883/4801 [00:56<00:05, 351.18it/s]
#
#
#
#
#
#
#  63%|██████▎   | 3014/4801 [00:56<00:03, 449.75it/s]
#
#
#
#
#
#
#  65%|██████▌   | 3138/4801 [00:56<00:02, 555.75it/s]
#
#
#
#
#
#
#  68%|██████▊   | 3263/4801 [00:56<00:02, 666.14it/s]
#
#
#
#
#
#
#  71%|███████   | 3389/4801 [00:56<00:01, 775.71it/s]
#
#
#
#
#
#
#  73%|███████▎  | 3514/4801 [00:56<00:01, 875.23it/s]
#
#
#
#
#
#
#  76%|███████▌  | 3647/4801 [00:56<00:01, 975.07it/s]
#
#
#
#
#
#
#  79%|███████▉  | 3782/4801 [00:56<00:00, 1063.46it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3919/4801 [00:56<00:00, 1138.32it/s]
#
#
#
#
#
#
#  84%|████████▍ | 4050/4801 [00:56<00:00, 1156.62it/s]
#
#
#
#
#
#
#  87%|████████▋ | 4178/4801 [00:57<00:00, 1179.13it/s]
#
#
#
#
#
#
#  90%|████████▉ | 4310/4801 [00:57<00:00, 1216.86it/s]
#
#
#
#
#
#
#  93%|█████████▎| 4444/4801 [00:57<00:00, 1251.09it/s]
#
#
#
#
#
#
#  95%|█████████▌| 4574/4801 [00:57<00:00, 1251.98it/s]
#
#
#
#
#
#
# 100%|██████████| 4801/4801 [00:57<00:00, 83.49it/s]
#
#
#
#
#
#
# Universidades:  60%|██████    | 12/20 [25:01<42:32, 319.05s/it]
#
#
#
#
#
#
#   0%|          | 0/965 [00:00<?, ?it/s]
#
#
#
#
#
#
#   2%|▏         | 19/965 [00:00<00:05, 188.10it/s]
#
#
#
#
#
#
#   4%|▎         | 35/965 [00:00<00:05, 178.67it/s]
#
#
#
#
#
#
#   6%|▌         | 54/965 [00:00<00:05, 181.78it/s]
#
#
#
#
#
#
#   8%|▊         | 75/965 [00:00<00:04, 189.21it/s]
#
#
#
#
#
#
#   9%|▉         | 91/965 [00:00<00:04, 178.88it/s]
#
#
#
#
#
#
#  12%|█▏        | 112/965 [00:00<00:04, 185.20it/s]
#
#
#
#
#
#
#  13%|█▎        | 129/965 [00:00<00:04, 180.23it/s]
#
#
#
#
#
#
#  15%|█▌        | 148/965 [00:00<00:04, 182.79it/s]
#
#
#
#
#
#
#  17%|█▋        | 167/965 [00:00<00:04, 182.00it/s]
#
#
#
#
#
#
#  20%|██        | 194/965 [00:01<00:03, 200.75it/s]
#
#
#
#
#
#
#  22%|██▏       | 215/965 [00:01<00:03, 191.51it/s]
#
#
#
#
#
#
#  24%|██▍       | 235/965 [00:01<00:03, 192.22it/s]
#
#
#
#
#
#
#  27%|██▋       | 257/965 [00:01<00:03, 197.20it/s]
#
#
#
#
#
#
#  29%|██▊       | 277/965 [00:01<00:03, 190.93it/s]
#
#
#
#
#
#
#  31%|███       | 297/965 [00:01<00:03, 185.03it/s]
#
#
#
#
#
#
#  33%|███▎      | 316/965 [00:01<00:03, 179.51it/s]
#
#
#
#
#
#
#  36%|███▌      | 347/965 [00:01<00:03, 203.83it/s]
#
#
#
#
#
#
#  41%|████      | 392/965 [00:01<00:02, 243.67it/s]
#
#
#
#
#
#
#  44%|████▎     | 421/965 [00:02<00:02, 212.39it/s]
#
#
#
#
#
#
#  46%|████▌     | 446/965 [00:02<00:02, 209.99it/s]
#
#
#
#
#
#
#  49%|████▊     | 470/965 [00:02<00:02, 199.42it/s]
#
#
#
#
#
#
# 100%|██████████| 965/965 [00:02<00:00, 384.18it/s]
#
#
#
#
#
#
# Universidades:  65%|██████▌   | 13/20 [25:27<26:58, 231.25s/it]
#
#
#
#
#
#
#   0%|          | 0/462 [00:00<?, ?it/s]
#
#
#
#
#
#
#   6%|▋         | 29/462 [00:00<00:01, 289.31it/s]
#
#
#
#
#
#
#  15%|█▍        | 69/462 [00:00<00:01, 312.69it/s]
#
#
#
#
#
#
#  21%|██        | 98/462 [00:00<00:01, 302.00it/s]
#
#
#
#
#
#
#  26%|██▌       | 121/462 [00:00<00:01, 275.01it/s]
#
#
#
#
#
#
#  32%|███▏      | 148/462 [00:00<00:01, 273.22it/s]
#
#
#
#
#
#
#  40%|███▉      | 183/462 [00:00<00:00, 291.90it/s]
#
#
#
#
#
#
#  47%|████▋     | 219/462 [00:00<00:00, 309.10it/s]
#
#
#
#
#
#
# 100%|██████████| 462/462 [00:00<00:00, 564.83it/s]
#
#
#
#
#
#
# Universidades:  70%|███████   | 14/20 [25:33<16:22, 163.81s/it]
#
#
#
#
#
#
# 100%|██████████| 33/33 [00:00<00:00, 2379.85it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#
#
#
#
#
# Universidades:  75%|███████▌  | 15/20 [25:35<09:34, 114.98s/it]
#
#
#
#
#
#
# 100%|██████████| 27/27 [00:00<00:00, 1297.07it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#
#
#
#
#
# Universidades:  80%|████████  | 16/20 [25:36<05:23, 80.79s/it]
#
#
#
#
#
#
#   0%|          | 0/73 [00:00<?, ?it/s]
#
#
#
#
#
#
# 100%|██████████| 73/73 [00:00<00:00, 670.12it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#
#
#
#
#
# Universidades:  85%|████████▌ | 17/20 [25:37<02:51, 57.01s/it]
#
#
#
#
#
#
# 100%|██████████| 153/153 [00:00<00:00, 1549.42it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#
#
#
#
#
# Universidades:  90%|█████████ | 18/20 [25:39<01:20, 40.40s/it]
#
#
#
#
#
#
# 100%|██████████| 123/123 [00:00<00:00, 1361.59it/s]
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#
#
#
#
#
# Universidades:  95%|█████████▌| 19/20 [25:40<00:28, 28.75s/it]
#
#
#
#
#
#
#   0%|          | 0/3813 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|          | 3/3813 [00:00<02:15, 28.12it/s]
#
#
#
#
#
#
#   0%|          | 8/3813 [00:00<02:01, 31.37it/s]
#
#
#
#
#
#
#   0%|          | 14/3813 [00:00<01:46, 35.53it/s]
#
#
#
#
#
#
#   0%|          | 17/3813 [00:00<02:26, 25.85it/s]
#
#
#
#
#
#
#   1%|          | 22/3813 [00:00<02:08, 29.41it/s]
#
#
#
#
#
#
#   1%|          | 26/3813 [00:00<01:59, 31.73it/s]
#
#
#
#
#
#
#   1%|          | 33/3813 [00:00<01:40, 37.79it/s]
#
#
#
#
#
#
#   1%|          | 38/3813 [00:00<01:37, 38.73it/s]
#
#
#
#
#
#
#   1%|          | 43/3813 [00:01<01:35, 39.53it/s]
#
#
#
#
#
#
#   1%|▏         | 48/3813 [00:01<02:04, 30.31it/s]
#
#
#
#
#
#
#   1%|▏         | 53/3813 [00:01<01:53, 32.99it/s]
#
#
#
#
#
#
#   2%|▏         | 58/3813 [00:01<01:45, 35.46it/s]
#
#
#
#
#
#
#   2%|▏         | 63/3813 [00:01<01:41, 37.04it/s]
#
#
#
#
#
#
#   2%|▏         | 68/3813 [00:01<01:37, 38.50it/s]
#
#
#
#
#
#
#   2%|▏         | 73/3813 [00:01<01:35, 39.09it/s]
#
#
#
#
#
#
#   2%|▏         | 78/3813 [00:02<01:58, 31.48it/s]
#
#
#
#
#
#
#   2%|▏         | 83/3813 [00:02<01:48, 34.30it/s]
#
#
#
#
#
#
#   2%|▏         | 88/3813 [00:02<01:42, 36.31it/s]
#
#
#
#
#
#
#   2%|▏         | 93/3813 [00:02<01:38, 37.86it/s]
#
#
#
#
#
#
#   3%|▎         | 98/3813 [00:02<01:34, 39.20it/s]
#
#
#
#
#
#
#   3%|▎         | 103/3813 [00:02<01:34, 39.06it/s]
#
#
#
#
#
#
#   3%|▎         | 108/3813 [00:03<02:03, 29.89it/s]
#
#
#
#
#
#
#   3%|▎         | 113/3813 [00:03<01:53, 32.55it/s]
#
#
#
#
#
#
#   3%|▎         | 117/3813 [00:03<01:47, 34.32it/s]
#
#
#
#
#
#
#   3%|▎         | 122/3813 [00:03<01:41, 36.53it/s]
#
#
#
#
#
#
#   3%|▎         | 127/3813 [00:03<01:37, 37.90it/s]
#
#
#
#
#
#
#   3%|▎         | 132/3813 [00:03<01:33, 39.39it/s]
#
#
#
#
#
#
#   4%|▎         | 137/3813 [00:03<02:01, 30.26it/s]
#
#
#
#
#
#
#   4%|▎         | 142/3813 [00:03<01:50, 33.22it/s]
#
#
#
#
#
#
#   4%|▍         | 148/3813 [00:04<01:38, 37.15it/s]
#
#
#
#
#
#
#   4%|▍         | 153/3813 [00:04<01:35, 38.49it/s]
#
#
#
#
#
#
#   4%|▍         | 158/3813 [00:04<01:31, 39.96it/s]
#
#
#
#
#
#
#   4%|▍         | 163/3813 [00:04<01:29, 40.89it/s]
#
#
#
#
#
#
#   4%|▍         | 168/3813 [00:04<01:56, 31.18it/s]
#
#
#
#
#
#
#   5%|▍         | 172/3813 [00:04<01:49, 33.23it/s]
#
#
#
#
#
#
#   5%|▍         | 176/3813 [00:04<01:45, 34.51it/s]
#
#
#
#
#
#
#   5%|▍         | 181/3813 [00:05<01:39, 36.67it/s]
#
#
#
#
#
#
#   5%|▍         | 186/3813 [00:05<01:34, 38.33it/s]
#
#
#
#
#
#
#   5%|▌         | 191/3813 [00:05<01:31, 39.65it/s]
#
#
#
#
#
#
#   5%|▌         | 196/3813 [00:05<01:29, 40.62it/s]
#
#
#
#
#
#
#   5%|▌         | 201/3813 [00:05<01:55, 31.18it/s]
#
#
#
#
#
#
#   5%|▌         | 206/3813 [00:05<01:46, 34.02it/s]
#
#
#
#
#
#
#   6%|▌         | 210/3813 [00:05<01:42, 35.28it/s]
#
#
#
#
#
#
#   6%|▌         | 215/3813 [00:05<01:37, 36.79it/s]
#
#
#
#
#
#
#   6%|▌         | 220/3813 [00:06<01:32, 38.66it/s]
#
#
#
#
#
#
#   6%|▌         | 225/3813 [00:06<01:29, 39.96it/s]
#
#
#
#
#
#
#   6%|▌         | 230/3813 [00:06<01:55, 31.09it/s]
#
#
#
#
#
#
#   6%|▌         | 235/3813 [00:06<01:45, 34.04it/s]
#
#
#
#
#
#
#   6%|▋         | 240/3813 [00:06<01:38, 36.35it/s]
#
#
#
#
#
#
#   6%|▋         | 245/3813 [00:06<01:34, 37.81it/s]
#
#
#
#
#
#
#   7%|▋         | 250/3813 [00:06<01:31, 39.12it/s]
#
#
#
#
#
#
#   7%|▋         | 255/3813 [00:07<01:28, 40.20it/s]
#
#
#
#
#
#
#   7%|▋         | 260/3813 [00:07<01:54, 30.92it/s]
#
#
#
#
#
#
#   7%|▋         | 265/3813 [00:07<01:46, 33.42it/s]
#
#
#
#
#
#
#   7%|▋         | 270/3813 [00:07<01:39, 35.60it/s]
#
#
#
#
#
#
#   7%|▋         | 274/3813 [00:07<01:36, 36.62it/s]
#
#
#
#
#
#
#   7%|▋         | 278/3813 [00:07<01:34, 37.30it/s]
#
#
#
#
#
#
#   7%|▋         | 282/3813 [00:07<01:34, 37.38it/s]
#
#
#
#
#
#
#   8%|▊         | 286/3813 [00:07<01:32, 38.06it/s]
#
#
#
#
#
#
#   8%|▊         | 290/3813 [00:08<02:07, 27.67it/s]
#
#
#
#
#
#
#   8%|▊         | 294/3813 [00:08<01:55, 30.42it/s]
#
#
#
#
#
#
#   8%|▊         | 302/3813 [00:08<01:36, 36.27it/s]
#
#
#
#
#
#
#   8%|▊         | 307/3813 [00:08<01:31, 38.19it/s]
#
#
#
#
#
#
#   8%|▊         | 312/3813 [00:08<01:29, 39.32it/s]
#
#
#
#
#
#
#   8%|▊         | 317/3813 [00:08<01:26, 40.31it/s]
#
#
#
#
#
#
#   8%|▊         | 322/3813 [00:08<01:57, 29.73it/s]
#
#
#
#
#
#
#   9%|▊         | 326/3813 [00:09<01:50, 31.46it/s]
#
#
#
#
#
#
#   9%|▊         | 331/3813 [00:09<01:42, 34.08it/s]
#
#
#
#
#
#
#   9%|▉         | 336/3813 [00:09<01:36, 36.00it/s]
#
#
#
#
#
#
#   9%|▉         | 341/3813 [00:09<01:32, 37.52it/s]
#
#
#
#
#
#
#   9%|▉         | 346/3813 [00:09<01:29, 38.73it/s]
#
#
#
#
#
#
#   9%|▉         | 351/3813 [00:09<01:59, 28.94it/s]
#
#
#
#
#
#
#   9%|▉         | 356/3813 [00:09<01:49, 31.68it/s]
#
#
#
#
#
#
#   9%|▉         | 361/3813 [00:10<01:40, 34.32it/s]
#
#
#
#
#
#
#  10%|▉         | 366/3813 [00:10<01:35, 36.10it/s]
#
#
#
#
#
#
#  10%|▉         | 370/3813 [00:10<01:32, 37.12it/s]
#
#
#
#
#
#
#  10%|▉         | 375/3813 [00:10<01:29, 38.35it/s]
#
#
#
#
#
#
#  10%|▉         | 380/3813 [00:10<01:54, 29.92it/s]
#
#
#
#
#
#
#  10%|█         | 385/3813 [00:10<01:44, 32.92it/s]
#
#
#
#
#
#
#  10%|█         | 390/3813 [00:10<01:37, 35.07it/s]
#
#
#
#
#
#
#  10%|█         | 394/3813 [00:11<01:34, 36.34it/s]
#
#
#
#
#
#
#  10%|█         | 399/3813 [00:11<01:28, 38.59it/s]
#
#
#
#
#
#
#  11%|█         | 404/3813 [00:11<01:24, 40.23it/s]
#
#
#
#
#
#
#  11%|█         | 409/3813 [00:11<01:49, 30.99it/s]
#
#
#
#
#
#
#  11%|█         | 414/3813 [00:11<01:40, 33.88it/s]
#
#
#
#
#
#
#  11%|█         | 421/3813 [00:11<01:27, 38.74it/s]
#
#
#
#
#
#
#  11%|█         | 426/3813 [00:11<01:27, 38.77it/s]
#
#
#
#
#
#
#  11%|█▏        | 434/3813 [00:11<01:16, 44.34it/s]
#
#
#
#
#
#
#  12%|█▏        | 440/3813 [00:12<01:13, 46.05it/s]
#
#
#
#
#
#
#  12%|█▏        | 445/3813 [00:12<01:43, 32.60it/s]
#
#
#
#
#
#
#  12%|█▏        | 450/3813 [00:12<01:35, 35.17it/s]
#
#
#
#
#
#
#  12%|█▏        | 456/3813 [00:12<01:25, 39.07it/s]
#
#
#
#
#
#
#  12%|█▏        | 461/3813 [00:12<01:24, 39.87it/s]
#
#
#
#
#
#
#  12%|█▏        | 466/3813 [00:12<01:22, 40.47it/s]
#
#
#
#
#
#
#  12%|█▏        | 471/3813 [00:12<01:21, 40.99it/s]
#
#
#
#
#
#
#  12%|█▏        | 476/3813 [00:13<01:20, 41.67it/s]
#
#
#
#
#
#
#  13%|█▎        | 481/3813 [00:13<01:44, 31.84it/s]
#
#
#
#
#
#
#  13%|█▎        | 485/3813 [00:13<01:38, 33.85it/s]
#
#
#
#
#
#
#  13%|█▎        | 490/3813 [00:13<01:31, 36.32it/s]
#
#
#
#
#
#
#  13%|█▎        | 495/3813 [00:13<01:27, 38.07it/s]
#
#
#
#
#
#
#  13%|█▎        | 500/3813 [00:13<01:23, 39.47it/s]
#
#
#
#
#
#
#  13%|█▎        | 505/3813 [00:13<01:24, 39.32it/s]
#
#
#
#
#
#
#  13%|█▎        | 510/3813 [00:14<01:48, 30.38it/s]
#
#
#
#
#
#
#  14%|█▎        | 515/3813 [00:14<01:38, 33.45it/s]
#
#
#
#
#
#
#  14%|█▎        | 520/3813 [00:14<01:31, 36.17it/s]
#
#
#
#
#
#
#  14%|█▍        | 525/3813 [00:14<01:25, 38.30it/s]
#
#
#
#
#
#
#  14%|█▍        | 530/3813 [00:14<01:23, 39.44it/s]
#
#
#
#
#
#
#  14%|█▍        | 536/3813 [00:14<01:17, 42.10it/s]
#
#
#
#
#
#
#  14%|█▍        | 541/3813 [00:14<01:47, 30.55it/s]
#
#
#
#
#
#
#  14%|█▍        | 546/3813 [00:15<01:38, 33.23it/s]
#
#
#
#
#
#
#  14%|█▍        | 550/3813 [00:15<01:34, 34.70it/s]
#
#
#
#
#
#
#  15%|█▍        | 555/3813 [00:15<01:27, 37.19it/s]
#
#
#
#
#
#
#  15%|█▍        | 560/3813 [00:15<01:23, 39.04it/s]
#
#
#
#
#
#
#  15%|█▍        | 565/3813 [00:15<01:20, 40.13it/s]
#
#
#
#
#
#
#  15%|█▍        | 570/3813 [00:15<01:50, 29.44it/s]
#
#
#
#
#
#
#  15%|█▌        | 574/3813 [00:15<01:42, 31.58it/s]
#
#
#
#
#
#
#  15%|█▌        | 579/3813 [00:16<01:34, 34.30it/s]
#
#
#
#
#
#
#  15%|█▌        | 584/3813 [00:16<01:27, 36.70it/s]
#
#
#
#
#
#
#  15%|█▌        | 589/3813 [00:16<01:24, 38.17it/s]
#
#
#
#
#
#
#  16%|█▌        | 594/3813 [00:16<01:20, 39.80it/s]
#
#
#
#
#
#
#  16%|█▌        | 599/3813 [00:16<01:44, 30.79it/s]
#
#
#
#
#
#
#  16%|█▌        | 604/3813 [00:16<01:34, 33.93it/s]
#
#
#
#
#
#
#  16%|█▌        | 610/3813 [00:16<01:25, 37.59it/s]
#
#
#
#
#
#
#  16%|█▌        | 615/3813 [00:16<01:22, 38.54it/s]
#
#
#
#
#
#
#  16%|█▋        | 620/3813 [00:17<01:19, 40.15it/s]
#
#
#
#
#
#
#  16%|█▋        | 625/3813 [00:17<01:16, 41.40it/s]
#
#
#
#
#
#
#  17%|█▋        | 630/3813 [00:17<01:39, 31.93it/s]
#
#
#
#
#
#
#  17%|█▋        | 635/3813 [00:17<01:30, 34.99it/s]
#
#
#
#
#
#
#  17%|█▋        | 640/3813 [00:17<01:24, 37.38it/s]
#
#
#
#
#
#
#  17%|█▋        | 645/3813 [00:17<01:21, 38.82it/s]
#
#
#
#
#
#
#  17%|█▋        | 652/3813 [00:17<01:10, 44.71it/s]
#
#
#
#
#
#
#  17%|█▋        | 657/3813 [00:18<01:12, 43.44it/s]
#
#
#
#
#
#
#  17%|█▋        | 662/3813 [00:18<01:43, 30.30it/s]
#
#
#
#
#
#
#  17%|█▋        | 667/3813 [00:18<01:35, 32.94it/s]
#
#
#
#
#
#
#  18%|█▊        | 671/3813 [00:18<01:31, 34.42it/s]
#
#
#
#
#
#
#  18%|█▊        | 676/3813 [00:18<01:26, 36.44it/s]
#
#
#
#
#
#
#  18%|█▊        | 680/3813 [00:18<01:24, 37.24it/s]
#
#
#
#
#
#
#  18%|█▊        | 686/3813 [00:18<01:17, 40.36it/s]
#
#
#
#
#
#
#  18%|█▊        | 691/3813 [00:19<01:44, 29.79it/s]
#
#
#
#
#
#
#  18%|█▊        | 696/3813 [00:19<01:35, 32.78it/s]
#
#
#
#
#
#
#  18%|█▊        | 700/3813 [00:19<01:31, 34.20it/s]
#
#
#
#
#
#
#  18%|█▊        | 704/3813 [00:19<01:28, 35.32it/s]
#
#
#
#
#
#
#  19%|█▊        | 710/3813 [00:19<01:18, 39.67it/s]
#
#
#
#
#
#
#  19%|█▉        | 720/3813 [00:19<01:05, 47.50it/s]
#
#
#
#
#
#
#  19%|█▉        | 726/3813 [00:19<01:23, 37.10it/s]
#
#
#
#
#
#
#  19%|█▉        | 731/3813 [00:20<01:20, 38.09it/s]
#
#
#
#
#
#
#  19%|█▉        | 736/3813 [00:20<01:16, 40.10it/s]
#
#
#
#
#
#
#  19%|█▉        | 741/3813 [00:20<01:13, 41.86it/s]
#
#
#
#
#
#
#  20%|█▉        | 749/3813 [00:20<01:04, 47.77it/s]
#
#
#
#
#
#
#  20%|█▉        | 755/3813 [00:20<01:04, 47.59it/s]
#
#
#
#
#
#
#  20%|█▉        | 761/3813 [00:20<01:25, 35.74it/s]
#
#
#
#
#
#
#  20%|██        | 766/3813 [00:20<01:19, 38.49it/s]
#
#
#
#
#
#
#  20%|██        | 771/3813 [00:21<01:18, 38.98it/s]
#
#
#
#
#
#
#  20%|██        | 776/3813 [00:21<01:14, 40.87it/s]
#
#
#
#
#
#
#  20%|██        | 781/3813 [00:21<01:11, 42.39it/s]
#
#
#
#
#
#
#  21%|██        | 786/3813 [00:21<01:34, 32.10it/s]
#
#
#
#
#
#
#  21%|██        | 791/3813 [00:21<01:25, 35.49it/s]
#
#
#
#
#
#
#  21%|██        | 796/3813 [00:21<01:19, 37.91it/s]
#
#
#
#
#
#
#  21%|██        | 801/3813 [00:21<01:14, 40.28it/s]
#
#
#
#
#
#
#  21%|██        | 808/3813 [00:21<01:06, 45.38it/s]
#
#
#
#
#
#
#  21%|██▏       | 813/3813 [00:22<01:09, 43.02it/s]
#
#
#
#
#
#
#  21%|██▏       | 818/3813 [00:22<01:31, 32.65it/s]
#
#
#
#
#
#
#  22%|██▏       | 824/3813 [00:22<01:21, 36.76it/s]
#
#
#
#
#
#
#  22%|██▏       | 829/3813 [00:22<01:16, 39.03it/s]
#
#
#
#
#
#
#  22%|██▏       | 834/3813 [00:22<01:12, 40.89it/s]
#
#
#
#
#
#
#  22%|██▏       | 844/3813 [00:22<01:01, 48.43it/s]
#
#
#
#
#
#
#  22%|██▏       | 850/3813 [00:22<01:02, 47.11it/s]
#
#
#
#
#
#
#  22%|██▏       | 856/3813 [00:23<01:24, 34.86it/s]
#
#
#
#
#
#
#  23%|██▎       | 861/3813 [00:23<01:18, 37.43it/s]
#
#
#
#
#
#
#  23%|██▎       | 872/3813 [00:23<01:03, 45.98it/s]
#
#
#
#
#
#
#  23%|██▎       | 879/3813 [00:23<01:03, 46.43it/s]
#
#
#
#
#
#
#  23%|██▎       | 885/3813 [00:23<01:03, 46.32it/s]
#
#
#
#
#
#
#  23%|██▎       | 891/3813 [00:23<01:23, 35.08it/s]
#
#
#
#
#
#
#  23%|██▎       | 896/3813 [00:24<01:16, 37.88it/s]
#
#
#
#
#
#
#  24%|██▎       | 901/3813 [00:24<01:13, 39.76it/s]
#
#
#
#
#
#
#  24%|██▍       | 906/3813 [00:24<01:10, 41.32it/s]
#
#
#
#
#
#
#  24%|██▍       | 911/3813 [00:24<01:08, 42.65it/s]
#
#
#
#
#
#
#  24%|██▍       | 916/3813 [00:24<01:29, 32.47it/s]
#
#
#
#
#
#
#  24%|██▍       | 921/3813 [00:24<01:20, 35.94it/s]
#
#
#
#
#
#
#  24%|██▍       | 927/3813 [00:24<01:11, 40.29it/s]
#
#
#
#
#
#
#  24%|██▍       | 932/3813 [00:24<01:08, 42.08it/s]
#
#
#
#
#
#
#  25%|██▍       | 937/3813 [00:24<01:05, 43.78it/s]
#
#
#
#
#
#
#  25%|██▍       | 942/3813 [00:25<01:05, 43.67it/s]
#
#
#
#
#
#
#  25%|██▍       | 947/3813 [00:25<01:26, 32.99it/s]
#
#
#
#
#
#
#  25%|██▍       | 953/3813 [00:25<01:16, 37.45it/s]
#
#
#
#
#
#
#  25%|██▌       | 958/3813 [00:25<01:11, 39.90it/s]
#
#
#
#
#
#
#  25%|██▌       | 963/3813 [00:25<01:07, 41.96it/s]
#
#
#
#
#
#
#  25%|██▌       | 969/3813 [00:25<01:03, 44.93it/s]
#
#
#
#
#
#
#  26%|██▌       | 974/3813 [00:25<01:03, 44.58it/s]
#
#
#
#
#
#
#  26%|██▌       | 979/3813 [00:26<01:22, 34.34it/s]
#
#
#
#
#
#
#  26%|██▌       | 984/3813 [00:26<01:15, 37.64it/s]
#
#
#
#
#
#
#  26%|██▌       | 989/3813 [00:26<01:10, 40.24it/s]
#
#
#
#
#
#
#  26%|██▌       | 994/3813 [00:26<01:06, 42.09it/s]
#
#
#
#
#
#
#  26%|██▌       | 999/3813 [00:26<01:05, 43.16it/s]
#
#
#
#
#
#
#  26%|██▋       | 1004/3813 [00:26<01:03, 44.51it/s]
#
#
#
#
#
#
#  26%|██▋       | 1009/3813 [00:26<01:21, 34.52it/s]
#
#
#
#
#
#
#  27%|██▋       | 1014/3813 [00:26<01:14, 37.36it/s]
#
#
#
#
#
#
#  27%|██▋       | 1022/3813 [00:27<01:04, 43.54it/s]
#
#
#
#
#
#
#  27%|██▋       | 1028/3813 [00:27<01:01, 45.12it/s]
#
#
#
#
#
#
#  27%|██▋       | 1034/3813 [00:27<00:57, 48.14it/s]
#
#
#
#
#
#
#  27%|██▋       | 1040/3813 [00:27<01:15, 36.81it/s]
#
#
#
#
#
#
#  27%|██▋       | 1045/3813 [00:27<01:10, 39.28it/s]
#
#
#
#
#
#
#  28%|██▊       | 1050/3813 [00:27<01:06, 41.56it/s]
#
#
#
#
#
#
#  28%|██▊       | 1056/3813 [00:27<01:00, 45.49it/s]
#
#
#
#
#
#
#  28%|██▊       | 1061/3813 [00:27<01:01, 44.85it/s]
#
#
#
#
#
#
#  28%|██▊       | 1066/3813 [00:28<01:00, 45.37it/s]
#
#
#
#
#
#
#  28%|██▊       | 1071/3813 [00:28<01:20, 34.03it/s]
#
#
#
#
#
#
#  28%|██▊       | 1076/3813 [00:28<01:13, 37.38it/s]
#
#
#
#
#
#
#  28%|██▊       | 1081/3813 [00:28<01:08, 40.15it/s]
#
#
#
#
#
#
#  28%|██▊       | 1086/3813 [00:28<01:04, 42.54it/s]
#
#
#
#
#
#
#  29%|██▊       | 1091/3813 [00:28<01:01, 43.99it/s]
#
#
#
#
#
#
#  29%|██▉       | 1099/3813 [00:28<00:54, 50.19it/s]
#
#
#
#
#
#
#  29%|██▉       | 1105/3813 [00:29<01:09, 38.88it/s]
#
#
#
#
#
#
#  29%|██▉       | 1110/3813 [00:29<01:06, 40.64it/s]
#
#
#
#
#
#
#  29%|██▉       | 1115/3813 [00:29<01:03, 42.70it/s]
#
#
#
#
#
#
#  29%|██▉       | 1120/3813 [00:29<01:01, 44.03it/s]
#
#
#
#
#
#
#  30%|██▉       | 1125/3813 [00:29<00:59, 45.24it/s]
#
#
#
#
#
#
#  30%|██▉       | 1130/3813 [00:29<00:58, 45.63it/s]
#
#
#
#
#
#
#  30%|██▉       | 1135/3813 [00:29<01:26, 30.86it/s]
#
#
#
#
#
#
#  30%|██▉       | 1143/3813 [00:30<01:12, 37.07it/s]
#
#
#
#
#
#
#  30%|███       | 1148/3813 [00:30<01:08, 38.89it/s]
#
#
#
#
#
#
#  30%|███       | 1153/3813 [00:30<01:05, 40.77it/s]
#
#
#
#
#
#
#  30%|███       | 1158/3813 [00:30<01:02, 42.63it/s]
#
#
#
#
#
#
#  31%|███       | 1163/3813 [00:30<01:01, 43.26it/s]
#
#
#
#
#
#
#  31%|███       | 1168/3813 [00:30<01:22, 32.11it/s]
#
#
#
#
#
#
#  31%|███       | 1173/3813 [00:30<01:14, 35.50it/s]
#
#
#
#
#
#
#  31%|███       | 1178/3813 [00:30<01:08, 38.25it/s]
#
#
#
#
#
#
#  31%|███       | 1184/3813 [00:31<01:02, 42.29it/s]
#
#
#
#
#
#
#  31%|███       | 1189/3813 [00:31<01:00, 43.40it/s]
#
#
#
#
#
#
#  31%|███▏      | 1194/3813 [00:31<00:58, 44.61it/s]
#
#
#
#
#
#
#  31%|███▏      | 1199/3813 [00:31<01:18, 33.45it/s]
#
#
#
#
#
#
#  32%|███▏      | 1205/3813 [00:31<01:10, 37.23it/s]
#
#
#
#
#
#
#  32%|███▏      | 1210/3813 [00:31<01:05, 39.63it/s]
#
#
#
#
#
#
#  32%|███▏      | 1215/3813 [00:31<01:01, 42.03it/s]
#
#
#
#
#
#
#  32%|███▏      | 1220/3813 [00:31<00:59, 43.29it/s]
#
#
#
#
#
#
#  32%|███▏      | 1225/3813 [00:32<00:59, 43.27it/s]
#
#
#
#
#
#
#  32%|███▏      | 1230/3813 [00:32<01:20, 32.07it/s]
#
#
#
#
#
#
#  32%|███▏      | 1236/3813 [00:32<01:09, 36.93it/s]
#
#
#
#
#
#
#  33%|███▎      | 1241/3813 [00:32<01:04, 39.60it/s]
#
#
#
#
#
#
#  33%|███▎      | 1247/3813 [00:32<00:59, 43.06it/s]
#
#
#
#
#
#
#  33%|███▎      | 1252/3813 [00:32<00:57, 44.38it/s]
#
#
#
#
#
#
#  33%|███▎      | 1257/3813 [00:32<00:56, 45.55it/s]
#
#
#
#
#
#
#  33%|███▎      | 1262/3813 [00:33<01:15, 33.78it/s]
#
#
#
#
#
#
#  33%|███▎      | 1268/3813 [00:33<01:08, 37.16it/s]
#
#
#
#
#
#
#  33%|███▎      | 1273/3813 [00:33<01:03, 39.75it/s]
#
#
#
#
#
#
#  34%|███▎      | 1278/3813 [00:33<01:00, 42.13it/s]
#
#
#
#
#
#
#  34%|███▎      | 1283/3813 [00:33<00:59, 42.44it/s]
#
#
#
#
#
#
#  34%|███▍      | 1288/3813 [00:33<00:57, 43.59it/s]
#
#
#
#
#
#
#  34%|███▍      | 1293/3813 [00:33<01:16, 32.97it/s]
#
#
#
#
#
#
#  34%|███▍      | 1298/3813 [00:33<01:09, 36.35it/s]
#
#
#
#
#
#
#  34%|███▍      | 1303/3813 [00:34<01:04, 39.20it/s]
#
#
#
#
#
#
#  34%|███▍      | 1308/3813 [00:34<01:00, 41.44it/s]
#
#
#
#
#
#
#  34%|███▍      | 1313/3813 [00:34<00:58, 42.98it/s]
#
#
#
#
#
#
#  35%|███▍      | 1319/3813 [00:34<00:55, 45.00it/s]
#
#
#
#
#
#
#  35%|███▍      | 1324/3813 [00:34<01:15, 32.95it/s]
#
#
#
#
#
#
#  35%|███▍      | 1329/3813 [00:34<01:09, 35.69it/s]
#
#
#
#
#
#
#  35%|███▍      | 1334/3813 [00:34<01:03, 39.00it/s]
#
#
#
#
#
#
#  35%|███▌      | 1339/3813 [00:34<01:00, 40.99it/s]
#
#
#
#
#
#
#  35%|███▌      | 1344/3813 [00:35<00:57, 43.03it/s]
#
#
#
#
#
#
#  35%|███▌      | 1349/3813 [00:35<00:55, 44.62it/s]
#
#
#
#
#
#
#  36%|███▌      | 1354/3813 [00:35<01:13, 33.37it/s]
#
#
#
#
#
#
#  36%|███▌      | 1360/3813 [00:35<01:05, 37.22it/s]
#
#
#
#
#
#
#  36%|███▌      | 1366/3813 [00:35<01:00, 40.53it/s]
#
#
#
#
#
#
#  36%|███▌      | 1371/3813 [00:35<00:57, 42.59it/s]
#
#
#
#
#
#
#  36%|███▌      | 1377/3813 [00:35<00:54, 44.86it/s]
#
#
#
#
#
#
#  36%|███▌      | 1382/3813 [00:36<01:11, 33.85it/s]
#
#
#
#
#
#
#  37%|███▋      | 1392/3813 [00:36<00:57, 42.15it/s]
#
#
#
#
#
#
#  37%|███▋      | 1398/3813 [00:36<00:55, 43.65it/s]
#
#
#
#
#
#
#  37%|███▋      | 1405/3813 [00:36<00:49, 48.92it/s]
#
#
#
#
#
#
#  37%|███▋      | 1412/3813 [00:36<00:46, 51.97it/s]
#
#
#
#
#
#
#  37%|███▋      | 1418/3813 [00:36<00:46, 51.87it/s]
#
#
#
#
#
#
#  37%|███▋      | 1424/3813 [00:36<01:01, 38.54it/s]
#
#
#
#
#
#
#  37%|███▋      | 1429/3813 [00:36<00:58, 40.52it/s]
#
#
#
#
#
#
#  38%|███▊      | 1434/3813 [00:37<00:56, 42.47it/s]
#
#
#
#
#
#
#  38%|███▊      | 1440/3813 [00:37<00:53, 44.60it/s]
#
#
#
#
#
#
#  38%|███▊      | 1445/3813 [00:37<00:52, 45.26it/s]
#
#
#
#
#
#
#  38%|███▊      | 1451/3813 [00:37<00:48, 48.24it/s]
#
#
#
#
#
#
#  38%|███▊      | 1457/3813 [00:37<01:04, 36.54it/s]
#
#
#
#
#
#
#  38%|███▊      | 1462/3813 [00:37<00:59, 39.35it/s]
#
#
#
#
#
#
#  38%|███▊      | 1468/3813 [00:37<00:55, 42.29it/s]
#
#
#
#
#
#
#  39%|███▊      | 1473/3813 [00:38<00:53, 43.84it/s]
#
#
#
#
#
#
#  39%|███▉      | 1478/3813 [00:38<00:52, 44.89it/s]
#
#
#
#
#
#
#  39%|███▉      | 1483/3813 [00:38<00:51, 45.31it/s]
#
#
#
#
#
#
#  39%|███▉      | 1488/3813 [00:38<01:10, 32.77it/s]
#
#
#
#
#
#
#  39%|███▉      | 1494/3813 [00:38<01:02, 36.90it/s]
#
#
#
#
#
#
#  39%|███▉      | 1500/3813 [00:38<00:57, 40.18it/s]
#
#
#
#
#
#
#  39%|███▉      | 1505/3813 [00:38<00:55, 41.94it/s]
#
#
#
#
#
#
#  40%|███▉      | 1510/3813 [00:38<00:52, 43.58it/s]
#
#
#
#
#
#
#  40%|███▉      | 1515/3813 [00:39<01:09, 33.11it/s]
#
#
#
#
#
#
#  40%|███▉      | 1520/3813 [00:39<01:03, 36.19it/s]
#
#
#
#
#
#
#  40%|███▉      | 1525/3813 [00:39<00:58, 39.44it/s]
#
#
#
#
#
#
#  40%|████      | 1532/3813 [00:39<00:50, 45.35it/s]
#
#
#
#
#
#
#  40%|████      | 1539/3813 [00:39<00:45, 50.40it/s]
#
#
#
#
#
#
#  41%|████      | 1546/3813 [00:39<00:41, 54.98it/s]
#
#
#
#
#
#
#  41%|████      | 1553/3813 [00:39<00:40, 55.59it/s]
#
#
#
#
#
#
#  41%|████      | 1559/3813 [00:40<00:57, 39.45it/s]
#
#
#
#
#
#
#  41%|████      | 1564/3813 [00:40<00:56, 39.83it/s]
#
#
#
#
#
#
#  41%|████      | 1570/3813 [00:40<00:50, 44.28it/s]
#
#
#
#
#
#
#  41%|████▏     | 1576/3813 [00:40<00:49, 45.45it/s]
#
#
#
#
#
#
#  41%|████▏     | 1581/3813 [00:40<00:47, 46.55it/s]
#
#
#
#
#
#
#  42%|████▏     | 1586/3813 [00:40<00:47, 47.34it/s]
#
#
#
#
#
#
#  42%|████▏     | 1591/3813 [00:40<01:06, 33.63it/s]
#
#
#
#
#
#
#  42%|████▏     | 1597/3813 [00:40<00:58, 38.19it/s]
#
#
#
#
#
#
#  42%|████▏     | 1603/3813 [00:41<00:53, 41.37it/s]
#
#
#
#
#
#
#  42%|████▏     | 1608/3813 [00:41<00:50, 43.60it/s]
#
#
#
#
#
#
#  42%|████▏     | 1614/3813 [00:41<00:47, 46.11it/s]
#
#
#
#
#
#
#  42%|████▏     | 1619/3813 [00:41<01:05, 33.40it/s]
#
#
#
#
#
#
#  43%|████▎     | 1626/3813 [00:41<00:56, 38.76it/s]
#
#
#
#
#
#
#  43%|████▎     | 1631/3813 [00:41<00:52, 41.28it/s]
#
#
#
#
#
#
#  43%|████▎     | 1636/3813 [00:41<00:51, 42.51it/s]
#
#
#
#
#
#
#  43%|████▎     | 1642/3813 [00:41<00:47, 45.91it/s]
#
#
#
#
#
#
#  43%|████▎     | 1649/3813 [00:42<00:42, 50.94it/s]
#
#
#
#
#
#
#  43%|████▎     | 1655/3813 [00:42<00:54, 39.43it/s]
#
#
#
#
#
#
#  44%|████▎     | 1660/3813 [00:42<00:52, 41.12it/s]
#
#
#
#
#
#
#  44%|████▎     | 1665/3813 [00:42<00:49, 43.42it/s]
#
#
#
#
#
#
#  44%|████▍     | 1670/3813 [00:42<00:47, 44.81it/s]
#
#
#
#
#
#
#  44%|████▍     | 1675/3813 [00:42<00:47, 44.91it/s]
#
#
#
#
#
#
#  44%|████▍     | 1680/3813 [00:42<00:46, 45.66it/s]
#
#
#
#
#
#
#  44%|████▍     | 1685/3813 [00:43<01:04, 33.19it/s]
#
#
#
#
#
#
#  44%|████▍     | 1691/3813 [00:43<00:56, 37.40it/s]
#
#
#
#
#
#
#  45%|████▍     | 1697/3813 [00:43<00:51, 40.72it/s]
#
#
#
#
#
#
#  45%|████▍     | 1702/3813 [00:43<00:50, 42.20it/s]
#
#
#
#
#
#
#  45%|████▍     | 1708/3813 [00:43<00:47, 44.73it/s]
#
#
#
#
#
#
#  45%|████▍     | 1713/3813 [00:43<00:46, 45.49it/s]
#
#
#
#
#
#
#  45%|████▌     | 1718/3813 [00:43<01:03, 33.23it/s]
#
#
#
#
#
#
#  45%|████▌     | 1723/3813 [00:43<00:57, 36.46it/s]
#
#
#
#
#
#
#  45%|████▌     | 1728/3813 [00:44<00:53, 39.05it/s]
#
#
#
#
#
#
#  45%|████▌     | 1733/3813 [00:44<00:50, 41.54it/s]
#
#
#
#
#
#
#  46%|████▌     | 1738/3813 [00:44<00:47, 43.54it/s]
#
#
#
#
#
#
#  46%|████▌     | 1743/3813 [00:44<00:46, 44.35it/s]
#
#
#
#
#
#
#  46%|████▌     | 1748/3813 [00:44<01:05, 31.71it/s]
#
#
#
#
#
#
#  46%|████▌     | 1753/3813 [00:44<00:59, 34.72it/s]
#
#
#
#
#
#
#  46%|████▌     | 1759/3813 [00:44<00:52, 39.17it/s]
#
#
#
#
#
#
#  46%|████▋     | 1764/3813 [00:44<00:49, 41.54it/s]
#
#
#
#
#
#
#  46%|████▋     | 1770/3813 [00:45<00:46, 43.98it/s]
#
#
#
#
#
#
#  47%|████▋     | 1775/3813 [00:45<00:45, 44.66it/s]
#
#
#
#
#
#
#  47%|████▋     | 1780/3813 [00:45<01:01, 32.90it/s]
#
#
#
#
#
#
#  47%|████▋     | 1785/3813 [00:45<00:55, 36.60it/s]
#
#
#
#
#
#
#  47%|████▋     | 1790/3813 [00:45<00:51, 39.66it/s]
#
#
#
#
#
#
#  47%|████▋     | 1796/3813 [00:45<00:46, 42.93it/s]
#
#
#
#
#
#
#  47%|████▋     | 1801/3813 [00:45<00:45, 44.70it/s]
#
#
#
#
#
#
#  47%|████▋     | 1808/3813 [00:45<00:41, 48.66it/s]
#
#
#
#
#
#
#  48%|████▊     | 1814/3813 [00:46<00:53, 37.67it/s]
#
#
#
#
#
#
#  48%|████▊     | 1820/3813 [00:46<00:48, 41.37it/s]
#
#
#
#
#
#
#  48%|████▊     | 1825/3813 [00:46<00:45, 43.41it/s]
#
#
#
#
#
#
#  48%|████▊     | 1830/3813 [00:46<00:44, 45.06it/s]
#
#
#
#
#
#
#  48%|████▊     | 1835/3813 [00:46<00:43, 45.93it/s]
#
#
#
#
#
#
#  48%|████▊     | 1841/3813 [00:46<00:40, 49.05it/s]
#
#
#
#
#
#
#  48%|████▊     | 1847/3813 [00:46<00:52, 37.44it/s]
#
#
#
#
#
#
#  49%|████▊     | 1853/3813 [00:47<00:47, 41.56it/s]
#
#
#
#
#
#
#  49%|████▉     | 1859/3813 [00:47<00:43, 44.84it/s]
#
#
#
#
#
#
#  49%|████▉     | 1865/3813 [00:47<00:41, 46.68it/s]
#
#
#
#
#
#
#  49%|████▉     | 1871/3813 [00:47<00:40, 47.70it/s]
#
#
#
#
#
#
#  49%|████▉     | 1877/3813 [00:47<00:53, 36.12it/s]
#
#
#
#
#
#
#  49%|████▉     | 1883/3813 [00:47<00:48, 39.89it/s]
#
#
#
#
#
#
#  50%|████▉     | 1889/3813 [00:47<00:44, 42.99it/s]
#
#
#
#
#
#
#  50%|████▉     | 1895/3813 [00:48<00:42, 45.40it/s]
#
#
#
#
#
#
#  50%|████▉     | 1901/3813 [00:48<00:40, 47.44it/s]
#
#
#
#
#
#
#  50%|█████     | 1907/3813 [00:48<00:51, 37.24it/s]
#
#
#
#
#
#
#  50%|█████     | 1913/3813 [00:48<00:45, 41.38it/s]
#
#
#
#
#
#
#  50%|█████     | 1919/3813 [00:48<00:42, 44.86it/s]
#
#
#
#
#
#
#  51%|█████     | 1926/3813 [00:48<00:38, 49.49it/s]
#
#
#
#
#
#
#  51%|█████     | 1932/3813 [00:48<00:36, 50.91it/s]
#
#
#
#
#
#
#  51%|█████     | 1938/3813 [00:49<00:48, 38.44it/s]
#
#
#
#
#
#
#  51%|█████     | 1944/3813 [00:49<00:44, 42.27it/s]
#
#
#
#
#
#
#  51%|█████     | 1950/3813 [00:49<00:41, 45.09it/s]
#
#
#
#
#
#
#  51%|█████▏    | 1956/3813 [00:49<00:40, 46.36it/s]
#
#
#
#
#
#
#  51%|█████▏    | 1962/3813 [00:49<00:38, 48.25it/s]
#
#
#
#
#
#
#  52%|█████▏    | 1968/3813 [00:49<00:49, 37.01it/s]
#
#
#
#
#
#
#  52%|█████▏    | 1974/3813 [00:49<00:44, 41.21it/s]
#
#
#
#
#
#
#  52%|█████▏    | 1980/3813 [00:50<00:41, 44.04it/s]
#
#
#
#
#
#
#  52%|█████▏    | 1986/3813 [00:50<00:39, 46.26it/s]
#
#
#
#
#
#
#  52%|█████▏    | 1992/3813 [00:50<00:37, 48.45it/s]
#
#
#
#
#
#
#  52%|█████▏    | 1998/3813 [00:50<00:50, 36.18it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2004/3813 [00:50<00:45, 40.05it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2010/3813 [00:50<00:41, 43.43it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2016/3813 [00:50<00:38, 46.35it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2022/3813 [00:50<00:37, 48.30it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2028/3813 [00:51<00:47, 37.33it/s]
#
#
#
#
#
#
#  53%|█████▎    | 2034/3813 [00:51<00:43, 41.08it/s]
#
#
#
#
#
#
#  54%|█████▎    | 2040/3813 [00:51<00:40, 44.08it/s]
#
#
#
#
#
#
#  54%|█████▎    | 2046/3813 [00:51<00:38, 46.04it/s]
#
#
#
#
#
#
#  54%|█████▍    | 2052/3813 [00:51<00:36, 48.06it/s]
#
#
#
#
#
#
#  54%|█████▍    | 2058/3813 [00:51<00:47, 37.05it/s]
#
#
#
#
#
#
#  54%|█████▍    | 2064/3813 [00:52<00:42, 40.81it/s]
#
#
#
#
#
#
#  54%|█████▍    | 2072/3813 [00:52<00:37, 46.71it/s]
#
#
#
#
#
#
#  55%|█████▍    | 2079/3813 [00:52<00:33, 51.34it/s]
#
#
#
#
#
#
#  55%|█████▍    | 2086/3813 [00:52<00:31, 54.97it/s]
#
#
#
#
#
#
#  55%|█████▍    | 2092/3813 [00:52<00:42, 40.14it/s]
#
#
#
#
#
#
#  55%|█████▌    | 2098/3813 [00:52<00:38, 44.05it/s]
#
#
#
#
#
#
#  55%|█████▌    | 2104/3813 [00:52<00:36, 47.25it/s]
#
#
#
#
#
#
#  55%|█████▌    | 2110/3813 [00:52<00:35, 48.35it/s]
#
#
#
#
#
#
#  55%|█████▌    | 2116/3813 [00:53<00:33, 50.25it/s]
#
#
#
#
#
#
#  56%|█████▌    | 2122/3813 [00:53<00:43, 38.63it/s]
#
#
#
#
#
#
#  56%|█████▌    | 2128/3813 [00:53<00:39, 42.32it/s]
#
#
#
#
#
#
#  56%|█████▌    | 2134/3813 [00:53<00:36, 45.67it/s]
#
#
#
#
#
#
#  56%|█████▌    | 2140/3813 [00:53<00:35, 47.46it/s]
#
#
#
#
#
#
#  56%|█████▋    | 2146/3813 [00:53<00:34, 48.64it/s]
#
#
#
#
#
#
#  56%|█████▋    | 2152/3813 [00:53<00:44, 37.19it/s]
#
#
#
#
#
#
#  57%|█████▋    | 2157/3813 [00:54<00:41, 40.03it/s]
#
#
#
#
#
#
#  57%|█████▋    | 2163/3813 [00:54<00:37, 43.56it/s]
#
#
#
#
#
#
#  57%|█████▋    | 2170/3813 [00:54<00:33, 48.45it/s]
#
#
#
#
#
#
#  57%|█████▋    | 2177/3813 [00:54<00:31, 52.18it/s]
#
#
#
#
#
#
#  57%|█████▋    | 2183/3813 [00:54<00:41, 39.11it/s]
#
#
#
#
#
#
#  57%|█████▋    | 2189/3813 [00:54<00:37, 42.82it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2195/3813 [00:54<00:34, 46.38it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2201/3813 [00:54<00:33, 48.31it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2207/3813 [00:55<00:32, 49.95it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2213/3813 [00:55<00:41, 38.80it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2219/3813 [00:55<00:37, 42.75it/s]
#
#
#
#
#
#
#  58%|█████▊    | 2225/3813 [00:55<00:34, 46.43it/s]
#
#
#
#
#
#
#  59%|█████▊    | 2231/3813 [00:55<00:32, 48.65it/s]
#
#
#
#
#
#
#  59%|█████▊    | 2237/3813 [00:55<00:31, 50.31it/s]
#
#
#
#
#
#
#  59%|█████▉    | 2243/3813 [00:55<00:40, 38.56it/s]
#
#
#
#
#
#
#  59%|█████▉    | 2249/3813 [00:56<00:36, 42.62it/s]
#
#
#
#
#
#
#  59%|█████▉    | 2255/3813 [00:56<00:33, 45.97it/s]
#
#
#
#
#
#
#  59%|█████▉    | 2261/3813 [00:56<00:32, 48.48it/s]
#
#
#
#
#
#
#  59%|█████▉    | 2267/3813 [00:56<00:30, 50.01it/s]
#
#
#
#
#
#
#  60%|█████▉    | 2273/3813 [00:56<00:40, 37.95it/s]
#
#
#
#
#
#
#  60%|█████▉    | 2279/3813 [00:56<00:36, 41.52it/s]
#
#
#
#
#
#
#  60%|█████▉    | 2285/3813 [00:56<00:33, 45.41it/s]
#
#
#
#
#
#
#  60%|██████    | 2292/3813 [00:56<00:30, 49.60it/s]
#
#
#
#
#
#
#  60%|██████    | 2298/3813 [00:57<00:29, 51.78it/s]
#
#
#
#
#
#
#  60%|██████    | 2304/3813 [00:57<00:38, 39.39it/s]
#
#
#
#
#
#
#  61%|██████    | 2311/3813 [00:57<00:33, 44.79it/s]
#
#
#
#
#
#
#  61%|██████    | 2317/3813 [00:57<00:31, 47.86it/s]
#
#
#
#
#
#
#  61%|██████    | 2324/3813 [00:57<00:29, 51.12it/s]
#
#
#
#
#
#
#  61%|██████    | 2330/3813 [00:57<00:28, 51.73it/s]
#
#
#
#
#
#
#  61%|██████▏   | 2336/3813 [00:58<00:38, 38.23it/s]
#
#
#
#
#
#
#  62%|██████▏   | 2349/3813 [00:58<00:30, 47.95it/s]
#
#
#
#
#
#
#  62%|██████▏   | 2356/3813 [00:58<00:28, 51.08it/s]
#
#
#
#
#
#
#  62%|██████▏   | 2363/3813 [00:58<00:27, 52.95it/s]
#
#
#
#
#
#
#  62%|██████▏   | 2370/3813 [00:58<00:26, 54.47it/s]
#
#
#
#
#
#
#  62%|██████▏   | 2377/3813 [00:58<00:34, 41.58it/s]
#
#
#
#
#
#
#  62%|██████▏   | 2383/3813 [00:58<00:31, 45.45it/s]
#
#
#
#
#
#
#  63%|██████▎   | 2389/3813 [00:58<00:29, 48.35it/s]
#
#
#
#
#
#
#  63%|██████▎   | 2395/3813 [00:59<00:27, 50.90it/s]
#
#
#
#
#
#
#  63%|██████▎   | 2401/3813 [00:59<00:27, 51.29it/s]
#
#
#
#
#
#
#  63%|██████▎   | 2407/3813 [00:59<00:36, 38.52it/s]
#
#
#
#
#
#
#  63%|██████▎   | 2413/3813 [00:59<00:32, 42.68it/s]
#
#
#
#
#
#
#  63%|██████▎   | 2419/3813 [00:59<00:30, 45.61it/s]
#
#
#
#
#
#
#  64%|██████▎   | 2425/3813 [00:59<00:28, 48.90it/s]
#
#
#
#
#
#
#  64%|██████▍   | 2433/3813 [00:59<00:25, 54.40it/s]
#
#
#
#
#
#
#  64%|██████▍   | 2439/3813 [01:00<00:33, 40.83it/s]
#
#
#
#
#
#
#  64%|██████▍   | 2445/3813 [01:00<00:30, 44.90it/s]
#
#
#
#
#
#
#  64%|██████▍   | 2451/3813 [01:00<00:28, 48.12it/s]
#
#
#
#
#
#
#  64%|██████▍   | 2457/3813 [01:00<00:26, 50.84it/s]
#
#
#
#
#
#
#  65%|██████▍   | 2463/3813 [01:00<00:25, 52.42it/s]
#
#
#
#
#
#
#  65%|██████▍   | 2469/3813 [01:00<00:34, 39.17it/s]
#
#
#
#
#
#
#  65%|██████▍   | 2474/3813 [01:00<00:32, 40.58it/s]
#
#
#
#
#
#
#  65%|██████▌   | 2479/3813 [01:00<00:31, 42.74it/s]
#
#
#
#
#
#
#  65%|██████▌   | 2486/3813 [01:01<00:27, 47.43it/s]
#
#
#
#
#
#
#  65%|██████▌   | 2492/3813 [01:01<00:26, 50.14it/s]
#
#
#
#
#
#
#  66%|██████▌   | 2501/3813 [01:01<00:22, 57.40it/s]
#
#
#
#
#
#
#  66%|██████▌   | 2508/3813 [01:01<00:29, 44.52it/s]
#
#
#
#
#
#
#  66%|██████▌   | 2514/3813 [01:01<00:27, 47.65it/s]
#
#
#
#
#
#
#  66%|██████▌   | 2520/3813 [01:01<00:26, 49.15it/s]
#
#
#
#
#
#
#  66%|██████▌   | 2526/3813 [01:01<00:25, 51.13it/s]
#
#
#
#
#
#
#  66%|██████▋   | 2533/3813 [01:01<00:23, 54.64it/s]
#
#
#
#
#
#
#  67%|██████▋   | 2539/3813 [01:02<00:31, 39.87it/s]
#
#
#
#
#
#
#  67%|██████▋   | 2545/3813 [01:02<00:28, 43.96it/s]
#
#
#
#
#
#
#  67%|██████▋   | 2551/3813 [01:02<00:26, 46.86it/s]
#
#
#
#
#
#
#  67%|██████▋   | 2561/3813 [01:02<00:22, 54.92it/s]
#
#
#
#
#
#
#  67%|██████▋   | 2568/3813 [01:02<00:22, 55.41it/s]
#
#
#
#
#
#
#  68%|██████▊   | 2575/3813 [01:02<00:29, 41.71it/s]
#
#
#
#
#
#
#  68%|██████▊   | 2581/3813 [01:02<00:27, 45.25it/s]
#
#
#
#
#
#
#  68%|██████▊   | 2587/3813 [01:03<00:25, 48.30it/s]
#
#
#
#
#
#
#  68%|██████▊   | 2593/3813 [01:03<00:23, 51.05it/s]
#
#
#
#
#
#
#  68%|██████▊   | 2599/3813 [01:03<00:22, 53.34it/s]
#
#
#
#
#
#
#  68%|██████▊   | 2606/3813 [01:03<00:29, 41.54it/s]
#
#
#
#
#
#
#  69%|██████▊   | 2612/3813 [01:03<00:26, 45.43it/s]
#
#
#
#
#
#
#  69%|██████▊   | 2618/3813 [01:03<00:24, 48.95it/s]
#
#
#
#
#
#
#  69%|██████▉   | 2624/3813 [01:03<00:23, 49.74it/s]
#
#
#
#
#
#
#  69%|██████▉   | 2630/3813 [01:03<00:22, 52.35it/s]
#
#
#
#
#
#
#  69%|██████▉   | 2637/3813 [01:04<00:20, 56.61it/s]
#
#
#
#
#
#
#  69%|██████▉   | 2643/3813 [01:04<00:27, 41.95it/s]
#
#
#
#
#
#
#  70%|██████▉   | 2652/3813 [01:04<00:23, 49.80it/s]
#
#
#
#
#
#
#  70%|██████▉   | 2659/3813 [01:04<00:21, 52.62it/s]
#
#
#
#
#
#
#  70%|██████▉   | 2666/3813 [01:04<00:20, 55.11it/s]
#
#
#
#
#
#
#  70%|███████   | 2673/3813 [01:04<00:20, 56.18it/s]
#
#
#
#
#
#
#  70%|███████   | 2680/3813 [01:04<00:25, 43.58it/s]
#
#
#
#
#
#
#  70%|███████   | 2687/3813 [01:05<00:23, 48.16it/s]
#
#
#
#
#
#
#  71%|███████   | 2695/3813 [01:05<00:20, 53.48it/s]
#
#
#
#
#
#
#  71%|███████   | 2702/3813 [01:05<00:19, 55.73it/s]
#
#
#
#
#
#
#  71%|███████   | 2709/3813 [01:05<00:19, 57.20it/s]
#
#
#
#
#
#
#  71%|███████   | 2716/3813 [01:05<00:25, 43.33it/s]
#
#
#
#
#
#
#  71%|███████▏  | 2723/3813 [01:05<00:22, 47.45it/s]
#
#
#
#
#
#
#  72%|███████▏  | 2729/3813 [01:05<00:21, 50.50it/s]
#
#
#
#
#
#
#  72%|███████▏  | 2735/3813 [01:06<00:20, 51.82it/s]
#
#
#
#
#
#
#  72%|███████▏  | 2742/3813 [01:06<00:25, 41.49it/s]
#
#
#
#
#
#
#  72%|███████▏  | 2748/3813 [01:06<00:23, 45.07it/s]
#
#
#
#
#
#
#  72%|███████▏  | 2755/3813 [01:06<00:21, 50.23it/s]
#
#
#
#
#
#
#  72%|███████▏  | 2762/3813 [01:06<00:19, 53.05it/s]
#
#
#
#
#
#
#  73%|███████▎  | 2768/3813 [01:06<00:19, 53.38it/s]
#
#
#
#
#
#
#  73%|███████▎  | 2774/3813 [01:06<00:19, 54.61it/s]
#
#
#
#
#
#
#  73%|███████▎  | 2780/3813 [01:07<00:25, 39.99it/s]
#
#
#
#
#
#
#  73%|███████▎  | 2787/3813 [01:07<00:22, 44.71it/s]
#
#
#
#
#
#
#  73%|███████▎  | 2794/3813 [01:07<00:20, 48.79it/s]
#
#
#
#
#
#
#  73%|███████▎  | 2801/3813 [01:07<00:19, 52.12it/s]
#
#
#
#
#
#
#  74%|███████▎  | 2807/3813 [01:07<00:18, 54.07it/s]
#
#
#
#
#
#
#  74%|███████▍  | 2813/3813 [01:07<00:25, 39.52it/s]
#
#
#
#
#
#
#  74%|███████▍  | 2820/3813 [01:07<00:22, 44.32it/s]
#
#
#
#
#
#
#  74%|███████▍  | 2827/3813 [01:07<00:20, 48.34it/s]
#
#
#
#
#
#
#  74%|███████▍  | 2837/3813 [01:08<00:17, 57.11it/s]
#
#
#
#
#
#
#  75%|███████▍  | 2844/3813 [01:08<00:16, 58.53it/s]
#
#
#
#
#
#
#  75%|███████▍  | 2851/3813 [01:08<00:21, 44.07it/s]
#
#
#
#
#
#
#  75%|███████▍  | 2858/3813 [01:08<00:19, 48.53it/s]
#
#
#
#
#
#
#  75%|███████▌  | 2865/3813 [01:08<00:18, 52.23it/s]
#
#
#
#
#
#
#  75%|███████▌  | 2871/3813 [01:08<00:17, 53.88it/s]
#
#
#
#
#
#
#  75%|███████▌  | 2878/3813 [01:08<00:21, 42.78it/s]
#
#
#
#
#
#
#  76%|███████▌  | 2885/3813 [01:09<00:19, 47.31it/s]
#
#
#
#
#
#
#  76%|███████▌  | 2892/3813 [01:09<00:17, 51.19it/s]
#
#
#
#
#
#
#  76%|███████▌  | 2899/3813 [01:09<00:16, 54.01it/s]
#
#
#
#
#
#
#  76%|███████▌  | 2906/3813 [01:09<00:16, 56.57it/s]
#
#
#
#
#
#
#  76%|███████▋  | 2912/3813 [01:09<00:21, 41.95it/s]
#
#
#
#
#
#
#  77%|███████▋  | 2918/3813 [01:09<00:19, 45.95it/s]
#
#
#
#
#
#
#  77%|███████▋  | 2925/3813 [01:09<00:17, 50.14it/s]
#
#
#
#
#
#
#  77%|███████▋  | 2931/3813 [01:09<00:16, 52.11it/s]
#
#
#
#
#
#
#  77%|███████▋  | 2939/3813 [01:10<00:15, 56.89it/s]
#
#
#
#
#
#
#  77%|███████▋  | 2946/3813 [01:10<00:19, 44.95it/s]
#
#
#
#
#
#
#  77%|███████▋  | 2953/3813 [01:10<00:17, 49.36it/s]
#
#
#
#
#
#
#  78%|███████▊  | 2960/3813 [01:10<00:16, 52.96it/s]
#
#
#
#
#
#
#  78%|███████▊  | 2967/3813 [01:10<00:15, 55.73it/s]
#
#
#
#
#
#
#  78%|███████▊  | 2973/3813 [01:10<00:14, 56.06it/s]
#
#
#
#
#
#
#  78%|███████▊  | 2979/3813 [01:10<00:19, 41.74it/s]
#
#
#
#
#
#
#  78%|███████▊  | 2986/3813 [01:11<00:17, 46.64it/s]
#
#
#
#
#
#
#  78%|███████▊  | 2992/3813 [01:11<00:17, 47.87it/s]
#
#
#
#
#
#
#  79%|███████▊  | 2999/3813 [01:11<00:15, 51.61it/s]
#
#
#
#
#
#
#  79%|███████▉  | 3006/3813 [01:11<00:14, 54.88it/s]
#
#
#
#
#
#
#  79%|███████▉  | 3012/3813 [01:11<00:19, 41.48it/s]
#
#
#
#
#
#
#  79%|███████▉  | 3019/3813 [01:11<00:17, 45.99it/s]
#
#
#
#
#
#
#  79%|███████▉  | 3026/3813 [01:11<00:15, 50.54it/s]
#
#
#
#
#
#
#  80%|███████▉  | 3033/3813 [01:11<00:14, 54.02it/s]
#
#
#
#
#
#
#  80%|███████▉  | 3040/3813 [01:12<00:13, 57.24it/s]
#
#
#
#
#
#
#  80%|███████▉  | 3047/3813 [01:12<00:17, 44.31it/s]
#
#
#
#
#
#
#  80%|████████  | 3054/3813 [01:12<00:15, 49.08it/s]
#
#
#
#
#
#
#  80%|████████  | 3061/3813 [01:12<00:14, 52.64it/s]
#
#
#
#
#
#
#  80%|████████  | 3068/3813 [01:12<00:13, 55.29it/s]
#
#
#
#
#
#
#  81%|████████  | 3075/3813 [01:12<00:12, 58.18it/s]
#
#
#
#
#
#
#  81%|████████  | 3082/3813 [01:13<00:16, 43.88it/s]
#
#
#
#
#
#
#  81%|████████  | 3089/3813 [01:13<00:15, 48.11it/s]
#
#
#
#
#
#
#  81%|████████  | 3096/3813 [01:13<00:13, 52.07it/s]
#
#
#
#
#
#
#  81%|████████▏ | 3103/3813 [01:13<00:12, 54.83it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3109/3813 [01:13<00:16, 41.58it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3116/3813 [01:13<00:15, 46.35it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3123/3813 [01:13<00:13, 50.11it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3130/3813 [01:13<00:12, 53.75it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3137/3813 [01:14<00:11, 56.83it/s]
#
#
#
#
#
#
#  82%|████████▏ | 3144/3813 [01:14<00:15, 44.27it/s]
#
#
#
#
#
#
#  83%|████████▎ | 3154/3813 [01:14<00:12, 52.28it/s]
#
#
#
#
#
#
#  83%|████████▎ | 3161/3813 [01:14<00:11, 55.80it/s]
#
#
#
#
#
#
#  83%|████████▎ | 3168/3813 [01:14<00:10, 58.86it/s]
#
#
#
#
#
#
#  83%|████████▎ | 3175/3813 [01:14<00:10, 60.32it/s]
#
#
#
#
#
#
#  83%|████████▎ | 3182/3813 [01:14<00:13, 45.52it/s]
#
#
#
#
#
#
#  84%|████████▎ | 3189/3813 [01:15<00:12, 49.60it/s]
#
#
#
#
#
#
#  84%|████████▍ | 3196/3813 [01:15<00:11, 54.07it/s]
#
#
#
#
#
#
#  84%|████████▍ | 3203/3813 [01:15<00:10, 57.25it/s]
#
#
#
#
#
#
#  84%|████████▍ | 3210/3813 [01:15<00:10, 58.80it/s]
#
#
#
#
#
#
#  84%|████████▍ | 3217/3813 [01:15<00:13, 45.61it/s]
#
#
#
#
#
#
#  85%|████████▍ | 3224/3813 [01:15<00:11, 50.43it/s]
#
#
#
#
#
#
#  85%|████████▍ | 3231/3813 [01:15<00:10, 54.62it/s]
#
#
#
#
#
#
#  85%|████████▍ | 3238/3813 [01:15<00:10, 57.14it/s]
#
#
#
#
#
#
#  85%|████████▌ | 3245/3813 [01:16<00:12, 43.71it/s]
#
#
#
#
#
#
#  85%|████████▌ | 3252/3813 [01:16<00:11, 48.65it/s]
#
#
#
#
#
#
#  85%|████████▌ | 3259/3813 [01:16<00:10, 52.45it/s]
#
#
#
#
#
#
#  86%|████████▌ | 3266/3813 [01:16<00:09, 55.85it/s]
#
#
#
#
#
#
#  86%|████████▌ | 3273/3813 [01:16<00:09, 58.18it/s]
#
#
#
#
#
#
#  86%|████████▌ | 3280/3813 [01:16<00:11, 45.09it/s]
#
#
#
#
#
#
#  86%|████████▌ | 3287/3813 [01:16<00:10, 49.10it/s]
#
#
#
#
#
#
#  86%|████████▋ | 3294/3813 [01:17<00:09, 53.03it/s]
#
#
#
#
#
#
#  87%|████████▋ | 3301/3813 [01:17<00:09, 56.23it/s]
#
#
#
#
#
#
#  87%|████████▋ | 3308/3813 [01:17<00:08, 58.66it/s]
#
#
#
#
#
#
#  87%|████████▋ | 3315/3813 [01:17<00:11, 44.44it/s]
#
#
#
#
#
#
#  87%|████████▋ | 3322/3813 [01:17<00:10, 48.86it/s]
#
#
#
#
#
#
#  87%|████████▋ | 3329/3813 [01:17<00:09, 52.55it/s]
#
#
#
#
#
#
#  87%|████████▋ | 3335/3813 [01:17<00:08, 54.55it/s]
#
#
#
#
#
#
#  88%|████████▊ | 3341/3813 [01:17<00:08, 55.00it/s]
#
#
#
#
#
#
#  88%|████████▊ | 3347/3813 [01:18<00:11, 41.24it/s]
#
#
#
#
#
#
#  88%|████████▊ | 3354/3813 [01:18<00:09, 46.43it/s]
#
#
#
#
#
#
#  88%|████████▊ | 3362/3813 [01:18<00:08, 52.62it/s]
#
#
#
#
#
#
#  89%|████████▉ | 3392/3813 [01:18<00:06, 69.90it/s]
#
#
#
#
#
#
#  93%|█████████▎| 3559/3813 [01:18<00:02, 98.10it/s]
#
#
#
#
#
#
# 100%|██████████| 3813/3813 [01:18<00:00, 48.43it/s]
#
#
#
#
#
#
# Universidades: 100%|██████████| 20/20 [36:01<00:00, 108.06s/it]

# %%
predictionsDic
# Out:
# {'ESPOL': {'AdamicAdar': {'Bagging': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509},
#    'SVC': {'accuracy': 0.9126733154950134,
#     'precision': 0.8333333333333334,
#     'recall': 0.12531328320802004,
#     'roc_auc': 0.5613096588453893},
#    'regresionLogistica': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9498905375820968,
#     'precision': 0.8271186440677966,
#     'recall': 0.6115288220551378,
#     'roc_auc': 0.7988947989586034},
#    'SVC': {'accuracy': 0.9053758209681343,
#     'precision': 0.75,
#     'recall': 0.03759398496240601,
#     'roc_auc': 0.5181235011018926},
#    'regresionLogistica': {'accuracy': 0.9498905375820968,
#     'precision': 0.8271186440677966,
#     'recall': 0.6115288220551378,
#     'roc_auc': 0.7988947989586034}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.9034298224276331,
#     'precision': 0.75,
#     'recall': 0.007518796992481203,
#     'roc_auc': 0.5036247002203786},
#    'SVC': {'accuracy': 0.9034298224276331,
#     'precision': 0.75,
#     'recall': 0.007518796992481203,
#     'roc_auc': 0.5036247002203786},
#    'regresionLogistica': {'accuracy': 0.9034298224276331,
#     'precision': 0.75,
#     'recall': 0.007518796992481203,
#     'roc_auc': 0.5036247002203786}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509},
#    'SVC': {'accuracy': 0.9014838238871321,
#     'precision': 0.35,
#     'recall': 0.017543859649122806,
#     'roc_auc': 0.5070208522383545},
#    'regresionLogistica': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509},
#    'SVC': {'accuracy': 0.9119435660423255,
#     'precision': 0.7846153846153846,
#     'recall': 0.12781954887218044,
#     'roc_auc': 0.5620239985740213},
#    'regresionLogistica': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9498905375820968,
#     'precision': 0.8271186440677966,
#     'recall': 0.6115288220551378,
#     'roc_auc': 0.7988947989586034},
#    'SVC': {'accuracy': 0.9053758209681343,
#     'precision': 0.75,
#     'recall': 0.03759398496240601,
#     'roc_auc': 0.5181235011018926},
#    'regresionLogistica': {'accuracy': 0.9498905375820968,
#     'precision': 0.8271186440677966,
#     'recall': 0.6115288220551378,
#     'roc_auc': 0.7988947989586034}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509},
#    'SVC': {'accuracy': 0.90221357333982,
#     'precision': 0.2,
#     'recall': 0.002506265664160401,
#     'roc_auc': 0.5007143397286319},
#    'regresionLogistica': {'accuracy': 0.9379712965215277,
#     'precision': 0.6714285714285714,
#     'recall': 0.706766917293233,
#     'roc_auc': 0.8347950965776509}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.916322062758453,
#     'precision': 0.5846153846153846,
#     'recall': 0.47619047619047616,
#     'roc_auc': 0.7199109708538588},
#    'SVC': {'accuracy': 0.9014838238871321,
#     'precision': 0.35,
#     'recall': 0.017543859649122806,
#     'roc_auc': 0.5070208522383545},
#    'regresionLogistica': {'accuracy': 0.916322062758453,
#     'precision': 0.5846153846153846,
#     'recall': 0.47619047619047616,
#     'roc_auc': 0.7199109708538588}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9297008027243979,
#     'precision': 0.6510989010989011,
#     'recall': 0.5939849624060151,
#     'roc_auc': 0.7798858001685248},
#    'SVC': {'accuracy': 0.9104840671369496,
#     'precision': 0.746031746031746,
#     'recall': 0.11779448621553884,
#     'roc_auc': 0.5567420706939764},
#    'regresionLogistica': {'accuracy': 0.9297008027243979,
#     'precision': 0.6519337016574586,
#     'recall': 0.5914786967418546,
#     'roc_auc': 0.7787673656123066}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9418632936025298,
#     'precision': 0.8225806451612904,
#     'recall': 0.5112781954887218,
#     'roc_auc': 0.7497123736064298},
#    'SVC': {'accuracy': 0.9053758209681343,
#     'precision': 0.75,
#     'recall': 0.03759398496240601,
#     'roc_auc': 0.5181235011018926},
#    'regresionLogistica': {'accuracy': 0.9418632936025298,
#     'precision': 0.8225806451612904,
#     'recall': 0.5112781954887218,
#     'roc_auc': 0.7497123736064298}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9175383118462661,
#     'precision': 0.6071428571428571,
#     'recall': 0.42606516290726815,
#     'roc_auc': 0.6982157711088065},
#    'SVC': {'accuracy': 0.90221357333982,
#     'precision': 0.2,
#     'recall': 0.002506265664160401,
#     'roc_auc': 0.5007143397286319},
#    'regresionLogistica': {'accuracy': 0.9175383118462661,
#     'precision': 0.6071428571428571,
#     'recall': 0.42606516290726815,
#     'roc_auc': 0.6982157711088065}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.9348090488932134,
#     'precision': 0.6775067750677507,
#     'recall': 0.6265664160401002,
#     'roc_auc': 0.7972541131924639},
#    'SVC': {'accuracy': 0.9136463147652639,
#     'precision': 0.6208791208791209,
#     'recall': 0.2832080200501253,
#     'roc_auc': 0.6323098289905799},
#    'regresionLogistica': {'accuracy': 0.9348090488932134,
#     'precision': 0.6775067750677507,
#     'recall': 0.6265664160401002,
#     'roc_auc': 0.7972541131924639}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9297008027243979,
#     'precision': 0.6519337016574586,
#     'recall': 0.5914786967418546,
#     'roc_auc': 0.7787673656123066},
#    'SVC': {'accuracy': 0.9267818049136464,
#     'precision': 0.9016393442622951,
#     'recall': 0.2756892230576441,
#     'roc_auc': 0.6362282322184774},
#    'regresionLogistica': {'accuracy': 0.9309170518122112,
#     'precision': 0.6610644257703081,
#     'recall': 0.5914786967418546,
#     'roc_auc': 0.7794408569916169}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9421065434200925,
#     'precision': 0.8232931726907631,
#     'recall': 0.5137844611528822,
#     'roc_auc': 0.7509655064385101},
#    'SVC': {'accuracy': 0.9068353198735101,
#     'precision': 0.8076923076923077,
#     'recall': 0.05263157894736842,
#     'roc_auc': 0.5256422980943739},
#    'regresionLogistica': {'accuracy': 0.940403794697154,
#     'precision': 0.8181818181818182,
#     'recall': 0.49624060150375937,
#     'roc_auc': 0.7421935766139487}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9318900510824617,
#     'precision': 0.7003367003367004,
#     'recall': 0.5213032581453634,
#     'roc_auc': 0.7486634825209576},
#    'SVC': {'accuracy': 0.9297008027243979,
#     'precision': 0.9166666666666666,
#     'recall': 0.3032581453634085,
#     'roc_auc': 0.6501473916472215},
#    'regresionLogistica': {'accuracy': 0.9318900510824617,
#     'precision': 0.7003367003367004,
#     'recall': 0.5213032581453634,
#     'roc_auc': 0.7486634825209576}}},
#  'PUCC': {'AdamicAdar': {'Bagging': {'accuracy': 0.9574187159597294,
#     'precision': 0.5361111111111111,
#     'recall': 0.6795774647887324,
#     'roc_auc': 0.8253298579354919},
#    'SVC': {'accuracy': 0.9660009902624196,
#     'precision': 0.875,
#     'recall': 0.3204225352112676,
#     'roc_auc': 0.6590857264800927},
#    'regresionLogistica': {'accuracy': 0.9574187159597294,
#     'precision': 0.5361111111111111,
#     'recall': 0.6795774647887324,
#     'roc_auc': 0.8253298579354919}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9668262089453705,
#     'precision': 0.7004830917874396,
#     'recall': 0.5105633802816901,
#     'roc_auc': 0.7499137247728797},
#    'SVC': {'accuracy': 0.9577488034329097,
#     'precision': 0.868421052631579,
#     'recall': 0.11619718309859155,
#     'roc_auc': 0.5576656911163953},
#    'regresionLogistica': {'accuracy': 0.9668262089453705,
#     'precision': 0.7004830917874396,
#     'recall': 0.5105633802816901,
#     'roc_auc': 0.7499137247728797}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.8296748638389173,
#     'precision': 0.09957173447537473,
#     'recall': 0.3274647887323944,
#     'roc_auc': 0.5909185415523444},
#    'SVC': {'accuracy': 0.9536227100181548,
#     'precision': 0.7142857142857143,
#     'recall': 0.017605633802816902,
#     'roc_auc': 0.5086296567282483},
#    'regresionLogistica': {'accuracy': 0.8296748638389173,
#     'precision': 0.09957173447537473,
#     'recall': 0.3274647887323944,
#     'roc_auc': 0.5909185415523444}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.9409143423007097,
#     'precision': 0.4254032258064516,
#     'recall': 0.7429577464788732,
#     'roc_auc': 0.8468035485641119},
#    'SVC': {'accuracy': 0.9518072289156626,
#     'precision': 0.39473684210526316,
#     'recall': 0.0528169014084507,
#     'roc_auc': 0.5244171087128834},
#    'regresionLogistica': {'accuracy': 0.9409143423007097,
#     'precision': 0.4254032258064516,
#     'recall': 0.7429577464788732,
#     'roc_auc': 0.8468035485641119}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9574187159597294,
#     'precision': 0.5361111111111111,
#     'recall': 0.6795774647887324,
#     'roc_auc': 0.8253298579354919},
#    'SVC': {'accuracy': 0.9653408153160588,
#     'precision': 0.8425925925925926,
#     'recall': 0.3204225352112676,
#     'roc_auc': 0.6587394061337722},
#    'regresionLogistica': {'accuracy': 0.9574187159597294,
#     'precision': 0.5361111111111111,
#     'recall': 0.6795774647887324,
#     'roc_auc': 0.8253298579354919}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9678164713649117,
#     'precision': 0.7258883248730964,
#     'recall': 0.5035211267605634,
#     'roc_auc': 0.7470852387049571},
#    'SVC': {'accuracy': 0.9551081036474666,
#     'precision': 0.7727272727272727,
#     'recall': 0.05985915492957746,
#     'roc_auc': 0.5294966770318883},
#    'regresionLogistica': {'accuracy': 0.9669912526819607,
#     'precision': 0.7038834951456311,
#     'recall': 0.5105633802816901,
#     'roc_auc': 0.7500003048594597}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.9584089783792705,
#     'precision': 0.6176470588235294,
#     'recall': 0.29577464788732394,
#     'roc_auc': 0.6433851594414975},
#    'SVC': {'accuracy': 0.9519722726522528,
#     'precision': 0.41025641025641024,
#     'recall': 0.056338028169014086,
#     'roc_auc': 0.526177672093165},
#    'regresionLogistica': {'accuracy': 0.9584089783792705,
#     'precision': 0.6176470588235294,
#     'recall': 0.29577464788732394,
#     'roc_auc': 0.6433851594414975}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.9316718930516587,
#     'precision': 0.34953703703703703,
#     'recall': 0.5316901408450704,
#     'roc_auc': 0.7415160660935309},
#    'SVC': {'accuracy': 0.9518072289156626,
#     'precision': 0.39473684210526316,
#     'recall': 0.0528169014084507,
#     'roc_auc': 0.5244171087128834},
#    'regresionLogistica': {'accuracy': 0.9316718930516587,
#     'precision': 0.34953703703703703,
#     'recall': 0.5316901408450704,
#     'roc_auc': 0.7415160660935309}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.958739065852451,
#     'precision': 0.553125,
#     'recall': 0.6232394366197183,
#     'roc_auc': 0.7992387659289067},
#    'SVC': {'accuracy': 0.9612147219013039,
#     'precision': 0.7951807228915663,
#     'recall': 0.2323943661971831,
#     'roc_auc': 0.61472532162673},
#    'regresionLogistica': {'accuracy': 0.9584089783792705,
#     'precision': 0.5467836257309941,
#     'recall': 0.6584507042253521,
#     'roc_auc': 0.8158054386927626}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9617098531110745,
#     'precision': 0.6529411764705882,
#     'recall': 0.3908450704225352,
#     'roc_auc': 0.6903143101030424},
#    'SVC': {'accuracy': 0.9551081036474666,
#     'precision': 0.7727272727272727,
#     'recall': 0.05985915492957746,
#     'roc_auc': 0.5294966770318883},
#    'regresionLogistica': {'accuracy': 0.9617098531110745,
#     'precision': 0.6511627906976745,
#     'recall': 0.39436619718309857,
#     'roc_auc': 0.6919882933967441}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9514771414424823,
#     'precision': 0.46835443037974683,
#     'recall': 0.2605633802816901,
#     'roc_auc': 0.6230089628681177},
#    'SVC': {'accuracy': 0.9519722726522528,
#     'precision': 0.41025641025641024,
#     'recall': 0.056338028169014086,
#     'roc_auc': 0.526177672093165},
#    'regresionLogistica': {'accuracy': 0.9514771414424823,
#     'precision': 0.46835443037974683,
#     'recall': 0.2605633802816901,
#     'roc_auc': 0.6230089628681177}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.9381085987786764,
#     'precision': 0.3853904282115869,
#     'recall': 0.5387323943661971,
#     'roc_auc': 0.7482406560575574},
#    'SVC': {'accuracy': 0.9483413104472685,
#     'precision': 0.27692307692307694,
#     'recall': 0.06338028169014084,
#     'roc_auc': 0.5276208767758064},
#    'regresionLogistica': {'accuracy': 0.9381085987786764,
#     'precision': 0.3853904282115869,
#     'recall': 0.5387323943661971,
#     'roc_auc': 0.7482406560575574}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.958739065852451,
#     'precision': 0.553125,
#     'recall': 0.6232394366197183,
#     'roc_auc': 0.7992387659289067},
#    'SVC': {'accuracy': 0.9618748968476646,
#     'precision': 0.8271604938271605,
#     'recall': 0.23591549295774647,
#     'roc_auc': 0.616745625266752},
#    'regresionLogistica': {'accuracy': 0.9585740221158607,
#     'precision': 0.5483870967741935,
#     'recall': 0.6584507042253521,
#     'roc_auc': 0.8158920187793428}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9618748968476646,
#     'precision': 0.6568047337278107,
#     'recall': 0.3908450704225352,
#     'roc_auc': 0.6904008901896226},
#    'SVC': {'accuracy': 0.958904109589041,
#     'precision': 0.8723404255319149,
#     'recall': 0.1443661971830986,
#     'roc_auc': 0.5716636180720687},
#    'regresionLogistica': {'accuracy': 0.9615448093744843,
#     'precision': 0.6491228070175439,
#     'recall': 0.3908450704225352,
#     'roc_auc': 0.6902277300164624}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9496616603399901,
#     'precision': 0.45248868778280543,
#     'recall': 0.352112676056338,
#     'roc_auc': 0.6655801475519786},
#    'SVC': {'accuracy': 0.9627001155306156,
#     'precision': 0.881578947368421,
#     'recall': 0.23591549295774647,
#     'roc_auc': 0.6171785256996525},
#    'regresionLogistica': {'accuracy': 0.9496616603399901,
#     'precision': 0.45248868778280543,
#     'recall': 0.352112676056338,
#     'roc_auc': 0.6655801475519786}}},
#  'PUCP': {'AdamicAdar': {'Bagging': {'accuracy': 0.9310148232611174,
#     'precision': 0.625,
#     'recall': 0.5228758169934641,
#     'roc_auc': 0.7464472776410169},
#    'SVC': {'accuracy': 0.9236031927023945,
#     'precision': 0.88,
#     'recall': 0.1437908496732026,
#     'roc_auc': 0.5709585104081191},
#    'regresionLogistica': {'accuracy': 0.9310148232611174,
#     'precision': 0.625,
#     'recall': 0.5228758169934641,
#     'roc_auc': 0.7464472776410169}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.936145952109464,
#     'precision': 0.711340206185567,
#     'recall': 0.45098039215686275,
#     'roc_auc': 0.7167456614125974},
#    'SVC': {'accuracy': 0.9179019384264538,
#     'precision': 0.8,
#     'recall': 0.0784313725490196,
#     'roc_auc': 0.5382787718460276},
#    'regresionLogistica': {'accuracy': 0.936145952109464,
#     'precision': 0.711340206185567,
#     'recall': 0.45098039215686275,
#     'roc_auc': 0.7167456614125974}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.7440136830102623,
#     'precision': 0.16055045871559634,
#     'recall': 0.45751633986928103,
#     'roc_auc': 0.6144546096598122},
#    'SVC': {'accuracy': 0.9133409350057012,
#     'precision': 0.6,
#     'recall': 0.0196078431372549,
#     'roc_auc': 0.5091793119496393},
#    'regresionLogistica': {'accuracy': 0.7440136830102623,
#     'precision': 0.16055045871559634,
#     'recall': 0.45751633986928103,
#     'roc_auc': 0.6144546096598122}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.9190421892816419,
#     'precision': 0.5265700483091788,
#     'recall': 0.7124183006535948,
#     'roc_auc': 0.825603278996379},
#    'SVC': {'accuracy': 0.9110604332953249,
#     'precision': 0.2,
#     'recall': 0.006535947712418301,
#     'roc_auc': 0.5020187546182329},
#    'regresionLogistica': {'accuracy': 0.9190421892816419,
#     'precision': 0.5265700483091788,
#     'recall': 0.7124183006535948,
#     'roc_auc': 0.825603278996379}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9327251995438997,
#     'precision': 0.6548672566371682,
#     'recall': 0.48366013071895425,
#     'roc_auc': 0.7296501777892086},
#    'SVC': {'accuracy': 0.9161915621436716,
#     'precision': 0.7142857142857143,
#     'recall': 0.06535947712418301,
#     'roc_auc': 0.5314305193241152},
#    'regresionLogistica': {'accuracy': 0.9310148232611174,
#     'precision': 0.625,
#     'recall': 0.5228758169934641,
#     'roc_auc': 0.7464472776410169}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9384264538198404,
#     'precision': 0.7922077922077922,
#     'recall': 0.39869281045751637,
#     'roc_auc': 0.6943495282768531},
#    'SVC': {'accuracy': 0.9179019384264538,
#     'precision': 0.8,
#     'recall': 0.0784313725490196,
#     'roc_auc': 0.5382787718460276},
#    'regresionLogistica': {'accuracy': 0.9384264538198404,
#     'precision': 0.7922077922077922,
#     'recall': 0.39869281045751637,
#     'roc_auc': 0.6943495282768531}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.9230330672748005,
#     'precision': 0.6071428571428571,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.6563606079533625},
#    'SVC': {'accuracy': 0.9116305587229191,
#     'precision': 0.4,
#     'recall': 0.026143790849673203,
#     'roc_auc': 0.5111980665678721},
#    'regresionLogistica': {'accuracy': 0.9230330672748005,
#     'precision': 0.6071428571428571,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.6563606079533625}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.9099201824401368,
#     'precision': 0.48427672955974843,
#     'recall': 0.5032679738562091,
#     'roc_auc': 0.7260249925495912},
#    'SVC': {'accuracy': 0.9110604332953249,
#     'precision': 0.2,
#     'recall': 0.006535947712418301,
#     'roc_auc': 0.5020187546182329},
#    'regresionLogistica': {'accuracy': 0.9099201824401368,
#     'precision': 0.48427672955974843,
#     'recall': 0.5032679738562091,
#     'roc_auc': 0.7260249925495912}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9338654503990877,
#     'precision': 0.6907216494845361,
#     'recall': 0.43790849673202614,
#     'roc_auc': 0.709585104081191},
#    'SVC': {'accuracy': 0.9161915621436716,
#     'precision': 0.7142857142857143,
#     'recall': 0.06535947712418301,
#     'roc_auc': 0.5314305193241152},
#    'regresionLogistica': {'accuracy': 0.9321550741163056,
#     'precision': 0.67,
#     'recall': 0.43790849673202614,
#     'roc_auc': 0.7086481896527088}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.935005701254276,
#     'precision': 0.819672131147541,
#     'recall': 0.32679738562091504,
#     'roc_auc': 0.6599633399060227},
#    'SVC': {'accuracy': 0.9179019384264538,
#     'precision': 0.8,
#     'recall': 0.0784313725490196,
#     'roc_auc': 0.5382787718460276},
#    'regresionLogistica': {'accuracy': 0.93557582668187,
#     'precision': 0.8225806451612904,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.6632313137622319}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9167616875712656,
#     'precision': 0.5660377358490566,
#     'recall': 0.19607843137254902,
#     'roc_auc': 0.590856205067911},
#    'SVC': {'accuracy': 0.9116305587229191,
#     'precision': 0.4,
#     'recall': 0.026143790849673203,
#     'roc_auc': 0.5111980665678721},
#    'regresionLogistica': {'accuracy': 0.9156214367160775,
#     'precision': 0.543859649122807,
#     'recall': 0.20261437908496732,
#     'roc_auc': 0.5931872644956379}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.9139110604332953,
#     'precision': 0.5055555555555555,
#     'recall': 0.5947712418300654,
#     'roc_auc': 0.7695904928700608},
#    'SVC': {'accuracy': 0.9156214367160775,
#     'precision': 0.5225225225225225,
#     'recall': 0.3790849673202614,
#     'roc_auc': 0.6729903287569452},
#    'regresionLogistica': {'accuracy': 0.9139110604332953,
#     'precision': 0.5055555555555555,
#     'recall': 0.5947712418300654,
#     'roc_auc': 0.7695904928700608}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9338654503990877,
#     'precision': 0.6907216494845361,
#     'recall': 0.43790849673202614,
#     'roc_auc': 0.709585104081191},
#    'SVC': {'accuracy': 0.927023945267959,
#     'precision': 0.9032258064516129,
#     'recall': 0.1830065359477124,
#     'roc_auc': 0.590566353545374},
#    'regresionLogistica': {'accuracy': 0.9332953249714937,
#     'precision': 0.6836734693877551,
#     'recall': 0.43790849673202614,
#     'roc_auc': 0.7092727992716971}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.93557582668187,
#     'precision': 0.8225806451612904,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.6632313137622319},
#    'SVC': {'accuracy': 0.9179019384264538,
#     'precision': 0.8,
#     'recall': 0.0784313725490196,
#     'roc_auc': 0.5382787718460276},
#    'regresionLogistica': {'accuracy': 0.93557582668187,
#     'precision': 0.8125,
#     'recall': 0.33986928104575165,
#     'roc_auc': 0.6661869828089471}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9133409350057012,
#     'precision': 0.5046728971962616,
#     'recall': 0.35294117647058826,
#     'roc_auc': 0.6599184333321086},
#    'SVC': {'accuracy': 0.9247434435575826,
#     'precision': 0.8181818181818182,
#     'recall': 0.17647058823529413,
#     'roc_auc': 0.5863614652606827},
#    'regresionLogistica': {'accuracy': 0.9133409350057012,
#     'precision': 0.5046728971962616,
#     'recall': 0.35294117647058826,
#     'roc_auc': 0.6599184333321086}}},
#  'TecMonterrey': {'AdamicAdar': {'Bagging': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213},
#    'SVC': {'accuracy': 0.9655810983397191,
#     'precision': 0.904,
#     'recall': 0.1765625,
#     'roc_auc': 0.587881782623169},
#    'regresionLogistica': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9762452107279693,
#     'precision': 0.8284313725490197,
#     'recall': 0.528125,
#     'roc_auc': 0.7617322736351532},
#    'SVC': {'accuracy': 0.9614303959131545,
#     'precision': 0.8913043478260869,
#     'recall': 0.0640625,
#     'roc_auc': 0.5318648052596537},
#    'regresionLogistica': {'accuracy': 0.9760536398467433,
#     'precision': 0.8496042216358839,
#     'recall': 0.503125,
#     'roc_auc': 0.7496650299600532}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.9590038314176246,
#     'precision': 0.3333333333333333,
#     'recall': 0.003125,
#     'roc_auc': 0.501429344207723},
#    'SVC': {'accuracy': 0.9590676883780332,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.49996671105193075},
#    'regresionLogistica': {'accuracy': 0.9590038314176246,
#     'precision': 0.3333333333333333,
#     'recall': 0.003125,
#     'roc_auc': 0.501429344207723}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213},
#    'SVC': {'accuracy': 0.9583652618135376,
#     'precision': 0.25,
#     'recall': 0.009375,
#     'roc_auc': 0.5040882989347536},
#    'regresionLogistica': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213},
#    'SVC': {'accuracy': 0.9656449553001277,
#     'precision': 0.9112903225806451,
#     'recall': 0.1765625,
#     'roc_auc': 0.5879150715712383},
#    'regresionLogistica': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9760536398467433,
#     'precision': 0.8496042216358839,
#     'recall': 0.503125,
#     'roc_auc': 0.7496650299600532},
#    'SVC': {'accuracy': 0.9614303959131545,
#     'precision': 0.8913043478260869,
#     'recall': 0.0640625,
#     'roc_auc': 0.5318648052596537},
#    'regresionLogistica': {'accuracy': 0.9760536398467433,
#     'precision': 0.8496042216358839,
#     'recall': 0.503125,
#     'roc_auc': 0.7496650299600532}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213},
#    'SVC': {'accuracy': 0.9588122605363985,
#     'precision': 0.14285714285714285,
#     'recall': 0.0015625,
#     'roc_auc': 0.5005815163115845},
#    'regresionLogistica': {'accuracy': 0.9724137931034482,
#     'precision': 0.6793103448275862,
#     'recall': 0.615625,
#     'roc_auc': 0.8016207556591213}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.9666666666666667,
#     'precision': 0.6244725738396625,
#     'recall': 0.4625,
#     'roc_auc': 0.725324567243675},
#    'SVC': {'accuracy': 0.9583652618135376,
#     'precision': 0.25,
#     'recall': 0.009375,
#     'roc_auc': 0.5040882989347536},
#    'regresionLogistica': {'accuracy': 0.9666666666666667,
#     'precision': 0.6244725738396625,
#     'recall': 0.4625,
#     'roc_auc': 0.725324567243675}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9699872286079183,
#     'precision': 0.6622137404580153,
#     'recall': 0.5421875,
#     'roc_auc': 0.7652016061917444},
#    'SVC': {'accuracy': 0.9646871008939975,
#     'precision': 0.8782608695652174,
#     'recall': 0.1578125,
#     'roc_auc': 0.5784402047270306},
#    'regresionLogistica': {'accuracy': 0.9696040868454662,
#     'precision': 0.6583011583011583,
#     'recall': 0.5328125,
#     'roc_auc': 0.7605141061917443}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9733077905491698,
#     'precision': 0.8404907975460123,
#     'recall': 0.428125,
#     'roc_auc': 0.7123314747003995},
#    'SVC': {'accuracy': 0.9614942528735633,
#     'precision': 0.9111111111111111,
#     'recall': 0.0640625,
#     'roc_auc': 0.531898094207723},
#    'regresionLogistica': {'accuracy': 0.9716475095785441,
#     'precision': 0.8402777777777778,
#     'recall': 0.378125,
#     'roc_auc': 0.6875312083888149}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9643039591315453,
#     'precision': 0.6103542234332425,
#     'recall': 0.35,
#     'roc_auc': 0.6702396804260986},
#    'SVC': {'accuracy': 0.9588122605363985,
#     'precision': 0.14285714285714285,
#     'recall': 0.0015625,
#     'roc_auc': 0.5005815163115845},
#    'regresionLogistica': {'accuracy': 0.9643039591315453,
#     'precision': 0.6103542234332425,
#     'recall': 0.35,
#     'roc_auc': 0.6702396804260986}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.9703703703703703,
#     'precision': 0.6654135338345865,
#     'recall': 0.553125,
#     'roc_auc': 0.7706370672436752},
#    'SVC': {'accuracy': 0.9666666666666667,
#     'precision': 0.625,
#     'recall': 0.4609375,
#     'roc_auc': 0.7245766061917444},
#    'regresionLogistica': {'accuracy': 0.9703703703703703,
#     'precision': 0.6654135338345865,
#     'recall': 0.553125,
#     'roc_auc': 0.7706370672436752}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9710089399744573,
#     'precision': 0.6703296703296703,
#     'recall': 0.571875,
#     'roc_auc': 0.7799454893475365},
#    'SVC': {'accuracy': 0.9662196679438059,
#     'precision': 0.9111111111111111,
#     'recall': 0.1921875,
#     'roc_auc': 0.595694282623169},
#    'regresionLogistica': {'accuracy': 0.9707535121328225,
#     'precision': 0.6697761194029851,
#     'recall': 0.5609375,
#     'roc_auc': 0.7745766061917445}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9734355044699873,
#     'precision': 0.8414634146341463,
#     'recall': 0.43125,
#     'roc_auc': 0.7138939747003995},
#    'SVC': {'accuracy': 0.9614942528735633,
#     'precision': 0.9111111111111111,
#     'recall': 0.0640625,
#     'roc_auc': 0.531898094207723},
#    'regresionLogistica': {'accuracy': 0.9715197956577267,
#     'precision': 0.8368055555555556,
#     'recall': 0.3765625,
#     'roc_auc': 0.6867166694407456}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9659642401021712,
#     'precision': 0.6301703163017032,
#     'recall': 0.4046875,
#     'roc_auc': 0.6972838298934754},
#    'SVC': {'accuracy': 0.9663473818646232,
#     'precision': 0.924812030075188,
#     'recall': 0.1921875,
#     'roc_auc': 0.5957608605193074},
#    'regresionLogistica': {'accuracy': 0.9657088122605364,
#     'precision': 0.6297229219143576,
#     'recall': 0.390625,
#     'roc_auc': 0.6904190246338215}}},
#  'UCNSA': {'AdamicAdar': {'Bagging': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9},
#    'SVC': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9},
#    'regresionLogistica': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6},
#    'SVC': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6},
#    'regresionLogistica': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9},
#    'SVC': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6},
#    'regresionLogistica': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6},
#    'SVC': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6},
#    'regresionLogistica': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.782608695652174,
#     'precision': 1.0,
#     'recall': 0.5,
#     'roc_auc': 0.75},
#    'SVC': {'accuracy': 0.6521739130434783,
#     'precision': 1.0,
#     'recall': 0.2,
#     'roc_auc': 0.6},
#    'regresionLogistica': {'accuracy': 0.782608695652174,
#     'precision': 1.0,
#     'recall': 0.5,
#     'roc_auc': 0.75}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.6956521739130435,
#     'precision': 0.7142857142857143,
#     'recall': 0.5,
#     'roc_auc': 0.673076923076923},
#    'SVC': {'accuracy': 0.5652173913043478,
#     'precision': 0.5,
#     'recall': 0.7,
#     'roc_auc': 0.5807692307692307},
#    'regresionLogistica': {'accuracy': 0.6956521739130435,
#     'precision': 0.7142857142857143,
#     'recall': 0.5,
#     'roc_auc': 0.673076923076923}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9},
#    'SVC': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9},
#    'regresionLogistica': {'accuracy': 0.9130434782608695,
#     'precision': 1.0,
#     'recall': 0.8,
#     'roc_auc': 0.9}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55},
#    'SVC': {'accuracy': 0.5652173913043478,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.6086956521739131,
#     'precision': 1.0,
#     'recall': 0.1,
#     'roc_auc': 0.55}}},
#  'UCV': {'AdamicAdar': {'Bagging': {'accuracy': 0.7222222222222222,
#     'precision': 0.5454545454545454,
#     'recall': 1.0,
#     'roc_auc': 0.7916666666666666},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7222222222222222,
#     'precision': 0.5454545454545454,
#     'recall': 1.0,
#     'roc_auc': 0.7916666666666666}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.2222222222222222,
#     'precision': 0.16666666666666666,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.24999999999999997}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.7222222222222222,
#     'precision': 0.5454545454545454,
#     'recall': 1.0,
#     'roc_auc': 0.7916666666666666},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7222222222222222,
#     'precision': 0.5454545454545454,
#     'recall': 1.0,
#     'roc_auc': 0.7916666666666666}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 1.0,
#     'precision': 1.0,
#     'recall': 1.0,
#     'roc_auc': 1.0},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7222222222222222,
#     'precision': 0.5454545454545454,
#     'recall': 1.0,
#     'roc_auc': 0.7916666666666666}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 1.0,
#     'precision': 1.0,
#     'recall': 1.0,
#     'roc_auc': 1.0},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.5555555555555556,
#     'precision': 0.3333333333333333,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7222222222222222,
#     'precision': 0.5454545454545454,
#     'recall': 1.0,
#     'roc_auc': 0.7916666666666666}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.6111111111111112,
#     'precision': 0.4444444444444444,
#     'recall': 0.6666666666666666,
#     'roc_auc': 0.6249999999999999},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.6111111111111112,
#     'precision': 0.4444444444444444,
#     'recall': 0.6666666666666666,
#     'roc_auc': 0.6249999999999999}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.8888888888888888,
#     'precision': 1.0,
#     'recall': 0.6666666666666666,
#     'roc_auc': 0.8333333333333333},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 1.0,
#     'precision': 1.0,
#     'recall': 1.0,
#     'roc_auc': 1.0},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.6666666666666666,
#     'precision': 0.5,
#     'recall': 0.6666666666666666,
#     'roc_auc': 0.6666666666666667},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.6111111111111112,
#     'precision': 0.4444444444444444,
#     'recall': 0.6666666666666666,
#     'roc_auc': 0.6249999999999999}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.7777777777777778,
#     'precision': 1.0,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.6666666666666666},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.5,
#     'precision': 0.2857142857142857,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.45833333333333326}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.8888888888888888,
#     'precision': 1.0,
#     'recall': 0.6666666666666666,
#     'roc_auc': 0.8333333333333333},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 1.0,
#     'precision': 1.0,
#     'recall': 1.0,
#     'roc_auc': 1.0},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7777777777777778,
#     'precision': 0.6,
#     'recall': 1.0,
#     'roc_auc': 0.8333333333333334}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.7777777777777778,
#     'precision': 1.0,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.6666666666666666},
#    'SVC': {'accuracy': 0.6666666666666666,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.5555555555555556,
#     'precision': 0.3333333333333333,
#     'recall': 0.3333333333333333,
#     'roc_auc': 0.5}}},
#  'UM': {'AdamicAdar': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.42857142857142855,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.3},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.42857142857142855,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.3}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.42857142857142855,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.3},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.42857142857142855,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.3}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.21428571428571427,
#     'precision': 0.1111111111111111,
#     'recall': 0.25,
#     'roc_auc': 0.22499999999999998},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.42857142857142855,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.3}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'SVC': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5},
#    'regresionLogistica': {'accuracy': 0.7142857142857143,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.5}}},
#  'UNAM': {'AdamicAdar': {'Bagging': {'accuracy': 0.9624334600760456,
#     'precision': 0.6628787878787878,
#     'recall': 0.5255255255255256,
#     'roc_auc': 0.755633637482404},
#    'SVC': {'accuracy': 0.9557414448669201,
#     'precision': 0.8888888888888888,
#     'recall': 0.14414414414414414,
#     'roc_auc': 0.5715914568846322},
#    'regresionLogistica': {'accuracy': 0.9624334600760456,
#     'precision': 0.6628787878787878,
#     'recall': 0.5255255255255256,
#     'roc_auc': 0.755633637482404}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9650190114068441,
#     'precision': 0.7668393782383419,
#     'recall': 0.4444444444444444,
#     'roc_auc': 0.7186176083164229},
#    'SVC': {'accuracy': 0.951787072243346,
#     'precision': 0.8636363636363636,
#     'recall': 0.057057057057057055,
#     'roc_auc': 0.5282882209348085},
#    'regresionLogistica': {'accuracy': 0.9644106463878327,
#     'precision': 0.7647058823529411,
#     'recall': 0.4294294294294294,
#     'roc_auc': 0.7111902033401553}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.8038022813688213,
#     'precision': 0.11192214111922141,
#     'recall': 0.4144144144144144,
#     'roc_auc': 0.6194949354994213},
#    'SVC': {'accuracy': 0.9492015209125475,
#     'precision': 0.4,
#     'recall': 0.006006006006006006,
#     'roc_auc': 0.5027626954092831},
# ...
#     'precision': 0.6818181818181818,
#     'recall': 0.17647058823529413,
#     'roc_auc': 0.5790729904527255},
#    'SVC': {'accuracy': 0.8244111349036403,
#     'precision': 0.7142857142857143,
#     'recall': 0.058823529411764705,
#     'roc_auc': 0.526793963658762},
#    'regresionLogistica': {'accuracy': 0.8372591006423983,
#     'precision': 0.7142857142857143,
#     'recall': 0.17647058823529413,
#     'roc_auc': 0.5803818909762858}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.8308351177730193,
#     'precision': 0.5714285714285714,
#     'recall': 0.2823529411764706,
#     'roc_auc': 0.6176162611641515},
#    'SVC': {'accuracy': 0.815845824411135,
#     'precision': 0.0,
#     'recall': 0.0,
#     'roc_auc': 0.4986910994764398},
#    'regresionLogistica': {'accuracy': 0.8308351177730193,
#     'precision': 0.5714285714285714,
#     'recall': 0.2823529411764706,
#     'roc_auc': 0.6176162611641515}}},
#  'Universidad de Chile': {'AdamicAdar': {'Bagging': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069},
#    'SVC': {'accuracy': 0.9885260370697264,
#     'precision': 0.8511904761904762,
#     'recall': 0.2851445663010967,
#     'roc_auc': 0.6421925978337389},
#    'regresionLogistica': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9870600026927162,
#     'precision': 0.5701219512195121,
#     'recall': 0.559322033898305,
#     'roc_auc': 0.7764488791689447},
#    'SVC': {'accuracy': 0.986267147366374,
#     'precision': 0.8014184397163121,
#     'recall': 0.11266201395812563,
#     'roc_auc': 0.5561183832016495},
#    'regresionLogistica': {'accuracy': 0.9867458524690712,
#     'precision': 0.5567410281280311,
#     'recall': 0.5722831505483549,
#     'roc_auc': 0.7826712514785392}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.7974329438867862,
#     'precision': 0.02615268329554044,
#     'recall': 0.34496510468594216,
#     'roc_auc': 0.5746452399075175},
#    'SVC': {'accuracy': 0.9847711939204452,
#     'precision': 0.2,
#     'recall': 0.004985044865403789,
#     'roc_auc': 0.5023406483059781},
#    'regresionLogistica': {'accuracy': 0.7974329438867862,
#     'precision': 0.02615268329554044,
#     'recall': 0.34496510468594216,
#     'roc_auc': 0.5746452399075175}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069},
#    'SVC': {'accuracy': 0.9843373674211259,
#     'precision': 0.3103448275862069,
#     'recall': 0.03589232303090728,
#     'roc_auc': 0.5173386650085586},
#    'regresionLogistica': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069},
#    'SVC': {'accuracy': 0.9868505692102861,
#     'precision': 0.7792792792792793,
#     'recall': 0.17248255234297108,
#     'roc_auc': 0.5858691845610123},
#    'regresionLogistica': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9874190315197391,
#     'precision': 0.5852631578947368,
#     'recall': 0.5543369890329013,
#     'roc_auc': 0.7741765742199924},
#    'SVC': {'accuracy': 0.9856538064535432,
#     'precision': 0.7,
#     'recall': 0.07676969092721835,
#     'roc_auc': 0.538134253154515},
#    'regresionLogistica': {'accuracy': 0.9874190315197391,
#     'precision': 0.5852631578947368,
#     'recall': 0.5543369890329013,
#     'roc_auc': 0.7741765742199924}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.9795652759286131,
#     'precision': 0.39019963702359345,
#     'recall': 0.6430707876370887,
#     'roc_auc': 0.8138809378316663},
#    'SVC': {'accuracy': 0.984292488817748,
#     'precision': 0.3025210084033613,
#     'recall': 0.03589232303090728,
#     'roc_auc': 0.51731588388955},
#    'regresionLogistica': {'accuracy': 0.9796251140664503,
#     'precision': 0.3910139647844566,
#     'recall': 0.6420737786640079,
#     'roc_auc': 0.8134204018768069}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.977007195536075,
#     'precision': 0.31509695290858725,
#     'recall': 0.45363908275174475,
#     'roc_auc': 0.7193093658093819},
#    'SVC': {'accuracy': 0.9843373674211259,
#     'precision': 0.3103448275862069,
#     'recall': 0.03589232303090728,
#     'roc_auc': 0.5173386650085586},
#    'regresionLogistica': {'accuracy': 0.977007195536075,
#     'precision': 0.31509695290858725,
#     'recall': 0.45363908275174475,
#     'roc_auc': 0.7193093658093819}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9795203973252352,
#     'precision': 0.3871763255240444,
#     'recall': 0.6261216350947159,
#     'roc_auc': 0.8055126734491864},
#    'SVC': {'accuracy': 0.9870899217616348,
#     'precision': 0.7916666666666666,
#     'recall': 0.18943170488534397,
#     'roc_auc': 0.5943361671258626},
#    'regresionLogistica': {'accuracy': 0.9795203973252352,
#     'precision': 0.3871763255240444,
#     'recall': 0.6261216350947159,
#     'roc_auc': 0.8055126734491864}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9871048812960941,
#     'precision': 0.5816917728852838,
#     'recall': 0.5004985044865404,
#     'roc_auc': 0.7475079242559062},
#    'SVC': {'accuracy': 0.9856687659880025,
#     'precision': 0.7064220183486238,
#     'recall': 0.07676969092721835,
#     'roc_auc': 0.5381418468608512},
#    'regresionLogistica': {'accuracy': 0.986895447813664,
#     'precision': 0.574793875147232,
#     'recall': 0.4865403788634098,
#     'roc_auc': 0.7405288614443408}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9772465480874235,
#     'precision': 0.3058470764617691,
#     'recall': 0.4067796610169492,
#     'roc_auc': 0.696358058441164},
#    'SVC': {'accuracy': 0.9845617604380151,
#     'precision': 0.3253012048192771,
#     'recall': 0.026919242273180457,
#     'roc_auc': 0.5130343735817637},
#    'regresionLogistica': {'accuracy': 0.9772465480874235,
#     'precision': 0.3058470764617691,
#     'recall': 0.4067796610169492,
#     'roc_auc': 0.696358058441164}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.9788172992056487,
#     'precision': 0.3640552995391705,
#     'recall': 0.551345962113659,
#     'roc_auc': 0.7683374607360712},
#    'SVC': {'accuracy': 0.9846515176447709,
#     'precision': 0.47306791569086654,
#     'recall': 0.20139581256231306,
#     'roc_auc': 0.598989322355514},
#    'regresionLogistica': {'accuracy': 0.9788172992056487,
#     'precision': 0.3640552995391705,
#     'recall': 0.551345962113659,
#     'roc_auc': 0.7683374607360712}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9795203973252352,
#     'precision': 0.3871763255240444,
#     'recall': 0.6261216350947159,
#     'roc_auc': 0.8055126734491864},
#    'SVC': {'accuracy': 0.9874190315197391,
#     'precision': 0.7934782608695652,
#     'recall': 0.21834496510468593,
#     'roc_auc': 0.6087396412911802},
#    'regresionLogistica': {'accuracy': 0.9797597498765839,
#     'precision': 0.39103362391033625,
#     'recall': 0.6261216350947159,
#     'roc_auc': 0.8056341727505656}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9869253668825826,
#     'precision': 0.5745664739884393,
#     'recall': 0.4955134596211366,
#     'roc_auc': 0.7449622458788508},
#    'SVC': {'accuracy': 0.9865513785211004,
#     'precision': 0.8333333333333334,
#     'recall': 0.1296111665004985,
#     'roc_auc': 0.5646081468855083},
#    'regresionLogistica': {'accuracy': 0.986895447813664,
#     'precision': 0.5744431418522861,
#     'recall': 0.4885343968095713,
#     'roc_auc': 0.7415106830047491}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9787574610678116,
#     'precision': 0.3461254612546125,
#     'recall': 0.4675972083748754,
#     'roc_auc': 0.7270705803735746},
#    'SVC': {'accuracy': 0.9849207892650381,
#     'precision': 0.4603174603174603,
#     'recall': 0.028913260219341975,
#     'roc_auc': 0.5141984440942406},
#    'regresionLogistica': {'accuracy': 0.9787574610678116,
#     'precision': 0.3461254612546125,
#     'recall': 0.4675972083748754,
#     'roc_auc': 0.7270705803735746}}},
#  'Universidad de Los Andes': {'AdamicAdar': {'Bagging': {'accuracy': 0.9345824071133694,
#     'precision': 0.5576208178438662,
#     'recall': 0.6329113924050633,
#     'roc_auc': 0.7960230038948394},
#    'SVC': {'accuracy': 0.9368053350269927,
#     'precision': 0.8518518518518519,
#     'recall': 0.1940928270042194,
#     'roc_auc': 0.5956727871284834},
#    'regresionLogistica': {'accuracy': 0.9345824071133694,
#     'precision': 0.5576208178438662,
#     'recall': 0.6329113924050633,
#     'roc_auc': 0.7960230038948394}},
#   'AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9536360749444268,
#     'precision': 0.7757575757575758,
#     'recall': 0.540084388185654,
#     'roc_auc': 0.7636891721148051},
#    'SVC': {'accuracy': 0.9301365512861226,
#     'precision': 0.8148148148148148,
#     'recall': 0.09282700421940929,
#     'roc_auc': 0.5455549856261881},
#    'regresionLogistica': {'accuracy': 0.9536360749444268,
#     'precision': 0.7757575757575758,
#     'recall': 0.540084388185654,
#     'roc_auc': 0.7636891721148051}},
#   'CommonKeywords': {'Bagging': {'accuracy': 0.7840584312480152,
#     'precision': 0.14100486223662884,
#     'recall': 0.3670886075949367,
#     'roc_auc': 0.5925415565447211},
#    'SVC': {'accuracy': 0.9244204509368054,
#     'precision': 0.42857142857142855,
#     'recall': 0.012658227848101266,
#     'roc_auc': 0.5056423007372375},
#    'regresionLogistica': {'accuracy': 0.7840584312480152,
#     'precision': 0.14100486223662884,
#     'recall': 0.3670886075949367,
#     'roc_auc': 0.5925415565447211}},
#   'CommonNeighbors': {'Bagging': {'accuracy': 0.9345824071133694,
#     'precision': 0.5576208178438662,
#     'recall': 0.6329113924050633,
#     'roc_auc': 0.7960230038948394},
#    'SVC': {'accuracy': 0.9241028898062877,
#     'precision': 0.46153846153846156,
#     'recall': 0.05063291139240506,
#     'roc_auc': 0.5229126095423564},
#    'regresionLogistica': {'accuracy': 0.9345824071133694,
#     'precision': 0.5576208178438662,
#     'recall': 0.6329113924050633,
#     'roc_auc': 0.7960230038948394}},
#   'CommonNeighbors-AdamicAdar': {'Bagging': {'accuracy': 0.9345824071133694,
#     'precision': 0.5576208178438662,
#     'recall': 0.6329113924050633,
#     'roc_auc': 0.7960230038948394},
#    'SVC': {'accuracy': 0.9368053350269927,
#     'precision': 0.8518518518518519,
#     'recall': 0.1940928270042194,
#     'roc_auc': 0.5956727871284834},
#    'regresionLogistica': {'accuracy': 0.9345824071133694,
#     'precision': 0.5576208178438662,
#     'recall': 0.6329113924050633,
#     'roc_auc': 0.7960230038948394}},
#   'CommonNeighbors-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9536360749444268,
#     'precision': 0.7757575757575758,
#     'recall': 0.540084388185654,
#     'roc_auc': 0.7636891721148051},
#    'SVC': {'accuracy': 0.9301365512861226,
#     'precision': 0.8148148148148148,
#     'recall': 0.09282700421940929,
#     'roc_auc': 0.5455549856261881},
#    'regresionLogistica': {'accuracy': 0.9536360749444268,
#     'precision': 0.7757575757575758,
#     'recall': 0.540084388185654,
#     'roc_auc': 0.7636891721148051}},
#   'CommonNeighbors-CommonKeywords': {'Bagging': {'accuracy': 0.9412511908542395,
#     'precision': 0.7241379310344828,
#     'recall': 0.35443037974683544,
#     'roc_auc': 0.6717206843789123},
#    'SVC': {'accuracy': 0.9237853286757701,
#     'precision': 0.45161290322580644,
#     'recall': 0.05907172995780591,
#     'roc_auc': 0.5266169089349468},
#    'regresionLogistica': {'accuracy': 0.934899968243887,
#     'precision': 0.5588235294117647,
#     'recall': 0.6413502109704642,
#     'roc_auc': 0.8000707098808366}},
#   'CommonNeighbors-JaccardCoeff': {'Bagging': {'accuracy': 0.9190219117180057,
#     'precision': 0.453125,
#     'recall': 0.3670886075949367,
#     'roc_auc': 0.6655154576436223},
#    'SVC': {'accuracy': 0.9241028898062877,
#     'precision': 0.46153846153846156,
#     'recall': 0.05063291139240506,
#     'roc_auc': 0.5229126095423564},
#    'regresionLogistica': {'accuracy': 0.9190219117180057,
#     'precision': 0.453125,
#     'recall': 0.3670886075949367,
#     'roc_auc': 0.6655154576436223}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9288663067640521,
#     'precision': 0.5288888888888889,
#     'recall': 0.5021097046413502,
#     'roc_auc': 0.7328543028701255},
#    'SVC': {'accuracy': 0.9355350905049222,
#     'precision': 0.8695652173913043,
#     'recall': 0.16877637130801687,
#     'roc_auc': 0.5833579658737886},
#    'regresionLogistica': {'accuracy': 0.9295014290250874,
#     'precision': 0.5330396475770925,
#     'recall': 0.510548523206751,
#     'roc_auc': 0.737073712152826}},
#   'CommonNeighbors-JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.9434741187678628,
#     'precision': 0.7610619469026548,
#     'recall': 0.3628691983122363,
#     'roc_auc': 0.6767986101451291},
#    'SVC': {'accuracy': 0.9304541124166402,
#     'precision': 0.8214285714285714,
#     'recall': 0.0970464135021097,
#     'roc_auc': 0.5476646902675383},
#    'regresionLogistica': {'accuracy': 0.9431565576373452,
#     'precision': 0.7543859649122807,
#     'recall': 0.3628691983122363,
#     'roc_auc': 0.6766269068484259}},
#   'CommonNeighbors-JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9320419180692283,
#     'precision': 0.6017699115044248,
#     'recall': 0.2869198312236287,
#     'roc_auc': 0.6357332672601659},
#    'SVC': {'accuracy': 0.9256906954588758,
#     'precision': 0.56,
#     'recall': 0.05907172995780591,
#     'roc_auc': 0.5276471287151667},
#    'regresionLogistica': {'accuracy': 0.9288663067640521,
#     'precision': 0.5503875968992248,
#     'recall': 0.29957805907172996,
#     'roc_auc': 0.6398302383270739}},
#   'JaccardCoeff': {'Bagging': {'accuracy': 0.9275960622419815,
#     'precision': 0.51931330472103,
#     'recall': 0.510548523206751,
#     'roc_auc': 0.7360434923726064},
#    'SVC': {'accuracy': 0.9291838678945697,
#     'precision': 0.5573770491803278,
#     'recall': 0.2869198312236287,
#     'roc_auc': 0.6341879375898363},
#    'regresionLogistica': {'accuracy': 0.9279136233724992,
#     'precision': 0.5213675213675214,
#     'recall': 0.5147679324894515,
#     'roc_auc': 0.7381531970139564}},
#   'JaccardCoeff-AdamicAdar': {'Bagging': {'accuracy': 0.9342648459828516,
#     'precision': 0.5675675675675675,
#     'recall': 0.5316455696202531,
#     'roc_auc': 0.7493392683266101},
#    'SVC': {'accuracy': 0.9383931406795808,
#     'precision': 0.9056603773584906,
#     'recall': 0.20253164556962025,
#     'roc_auc': 0.6004073063012936},
#    'regresionLogistica': {'accuracy': 0.9329946014607812,
#     'precision': 0.5570175438596491,
#     'recall': 0.5358649789029536,
#     'roc_auc': 0.7505904564844438}},
#   'JaccardCoeff-AdamicAdar-CommonKeywords': {'Bagging': {'accuracy': 0.947602413464592,
#     'precision': 0.7857142857142857,
#     'recall': 0.4177215189873418,
#     'roc_auc': 0.704224770482682},
#    'SVC': {'accuracy': 0.9301365512861226,
#     'precision': 0.8148148148148148,
#     'recall': 0.09282700421940929,
#     'roc_auc': 0.5455549856261881},
#    'regresionLogistica': {'accuracy': 0.9479199745951096,
#     'precision': 0.7874015748031497,
#     'recall': 0.4219409282700422,
#     'roc_auc': 0.706334475124032}},
#   'JaccardCoeff-CommonKeywords': {'Bagging': {'accuracy': 0.9368053350269927,
#     'precision': 0.625,
#     'recall': 0.4008438818565401,
#     'roc_auc': 0.6906348530161821},
#    'SVC': {'accuracy': 0.9244204509368054,
#     'precision': 0.42857142857142855,
#     'recall': 0.012658227848101266,
#     'roc_auc': 0.5056423007372375},
#    'regresionLogistica': {'accuracy': 0.9368053350269927,
#     'precision': 0.625,
#     'recall': 0.4008438818565401,
#     'roc_auc': 0.6906348530161821}}}}
