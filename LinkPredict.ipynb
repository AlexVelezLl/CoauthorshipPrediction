# %%
import networkx as nx
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.metrics import roc_auc_score

from tqdm import tqdm

coau_df = pd.read_csv("data/coauthorsCG-edges.csv",delimiter=";")
coau_df = coau_df[coau_df["Year"]>2015]
G = nx.from_pandas_edgelist(coau_df,"Source","Target",['Weight','Year'],create_using=nx.Graph())
nodos = list(G.nodes)
print(nx.number_connected_components(G))

coau_df.reset_index(drop=True, inplace=True)
nx.connected_components?
largest_cc = max(nx.connected_components(G),key=len)
largest_cc
# Out:
# 5
# {'Abad, A.G.',
#  'Abad, C.',
#  'Abad, C.L.',
#  'Adams, M.A.',
#  'Aelterman, J.',
#  'Aguilar, P.A.',
#  'Aguilera, C.',
#  'Aguilera, C.A.',
#  'Aguilera, F.J.',
#  'Akbarinia, A.',
#  'Alcivar, I.',
#  'Alcivar, R.',
#  'Alcivar-Molina, E.',
#  'Aller, J.M.',
#  'Alomari, A.',
#  'Alonso, G.E.',
#  'Altamirano, C.A.',
#  'Alvarado, A.',
#  'Alvarez-Alvarado, M.S.',
#  'Alves, G.R.',
#  'Alvia, S.V.',
#  'Andrade, B.',
#  'Andrade, X.',
#  'April, A.',
#  'Aragon, H.',
#  'Arana, R.C.',
#  'Arce, V.',
#  'Arce, V.A.',
#  'Armijos, A.F.',
#  'Arreaga, N.X.',
#  'Arévalo-Avecillas, D.',
#  'Asanza, V.',
#  'Atkin, J.',
#  'Aumala, G.',
#  'Avendaño, A.',
#  'Baidal, C.S.',
#  'Bajaña, B.',
#  'Baquerizo, G.',
#  'Barzola, V.E.',
#  'Bayona, O.',
#  'Bezemer, C.-P.',
#  'Blazquez, F.',
#  'Boratto, L.',
#  'Bosquez, C.',
#  'Boza, E.',
#  'Boza, E.F.',
#  'Bozhko, S.',
#  'Braeken, A.',
#  'Braganza, S.',
#  'Bruckman, A.',
#  'Brusilovsky, P.',
#  'Buckingham Shum, S.',
#  'Buil, M.P.',
#  'Buman, M.P.',
#  'Bustamante, J.C.',
#  'Cadena, A.',
#  'Caio, R.',
#  'Cajo, R.',
#  'Campana, F.',
#  'Campbell, R.H.',
#  'Capel, M.I.',
#  'Carrillo, G.E.',
#  'Carvajal Ayala, J.A.',
#  'Carvajal, J.A.',
#  'Carvajal, R.',
#  'Casas, A.P.',
#  'Castells, J.',
#  'Castillo, G.',
#  'Castillo-Lopez, G.',
#  'Castro, D.',
#  'Castro, R.',
#  'Castro, S.J.',
#  'Castro-Valladares, L.',
#  'Cechinel, C.',
#  'Cedeno, J.',
#  'Cedeño, J.',
#  'Cevallos, H.',
#  'Cevallos, J.',
#  'Cevallos-Cevallos, J.',
#  'Chalen, M.',
#  'Chalen, T.M.',
#  'Chalén, T.M.',
#  'Charco, J.L.',
#  'Chavez-Burbano, P.',
#  'Chiluiza, K.',
#  'Cipriano, D.',
#  'Cobos, R.',
#  'Collaguazo Jaramillo, A.',
#  'Collaguazo-Jaramillo, A.',
#  'Conati, C.',
#  'Concha, A.G.',
#  'Constantine, A.',
#  'Copot, C.',
#  'Coque, S.',
#  'Cordova Estrella, R.',
#  'Cordova-Garcia, J.',
#  'Cordova-Villagomez, J.',
#  'Cortez, D.',
#  'Criollo, R.',
#  'Cruz, E.',
#  'Cukurova, M.',
#  'Da Silva, B.',
#  'Danos, E.',
#  'Dawson, S.',
#  'De Kevser, R.',
#  'De Keyser, R.',
#  'De Laet, T.',
#  'De Lourdes Pilay, M.',
#  'Deligiannis, N.',
#  'Desiderio, K.',
#  'DiSalvo, B.',
#  'Dias, P.',
#  'Diaz, J.',
#  'Disalvo, B.',
#  'Do, T.H.',
#  'Dominguez, F.',
#  'Domínguez, F.',
#  'Donoso, D.E.O.',
#  'Dos Santos, H.L.',
#  'Douglas, A.',
#  'Dye, M.',
#  'Díaz, P.',
#  'Echeverria, V.',
#  'Ehsan, U.',
#  'Eismann, S.',
#  'Encalada, A.',
#  'Endara, I.',
#  'Eras, L.',
#  'Eslambolchilar, P.',
#  'Esparragoza, I.E.',
#  'Espinoza, J.R.',
#  'Estrada, R.L.',
#  'Estrada-Cedeno, P.',
#  'Evans, H.I.',
#  'Eyk, E.V.',
#  'Falcones, G.',
#  'Ferguson, R.',
#  'Ferme, V.',
#  'Ferrin, A.',
#  'Fiallos, A.',
#  'Fiallos, C.',
#  'Figueroa, S.',
#  'Flores, M.',
#  'Freigoun, M.T.',
#  'Garcia, J.C.',
#  'Garcia, K.C.',
#  'García, J.',
#  'García, S.',
#  'Garzon, A.',
#  'Gautama, S.',
#  'Gawanmeh, A.',
#  'Godoy, C.',
#  'Gonzalez, A.',
#  'Gorotiza, J.',
#  'Granda, R.',
#  'Gray, M.L.',
#  'Greer, J.',
#  'Grohmann, J.',
#  'Guaman, B.',
#  'Guamán, B.',
#  'Guaranda, M.-B.',
#  'Guerra, V.',
#  'Guingla, D.P.',
#  'Gutiérrez, F.',
#  'Hammoud, R.I.',
#  'Hayes, C.',
#  'Hekler, E.B.',
#  'Hernandez, J.',
#  'Herrera, E.V.',
#  'Hidalgo, J.I.',
#  'Hill, C.',
#  'Huilcapi, V.',
#  'Hurel, J.',
#  'Idrovo, R.M.',
#  'Intriago, G.',
#  'Intriago, R.',
#  'Intriago, R.P.',
#  'Ionescu, C.',
#  'Ionescu, C.M.',
#  'Iosup, A.',
#  'Ivashyn, U.',
#  'Izquierdo, E.',
#  'Jadan, H.I.V.',
#  'Jimenes, K.',
#  'Jimenez, A.',
#  'Jimmy Banchon, Z.',
#  'Jiménes, K.',
#  'Jiménez, A.',
#  'Jurado, D.',
#  'Jurado-Verdu, C.',
#  'Jácome, L.',
#  'Karusala, N.',
#  'Klasnja, P.',
#  'Korinek, E.V.',
#  'Kuffo, L.',
#  'Kuffó, L.',
#  'Kumar, A.',
#  'Kumar, N.',
#  'Lara, P.',
#  'Larrea, J.',
#  'Lascano, S.',
#  'Lasso, H.',
#  'Layedra, F.',
#  'Lemos dos Santos, H.',
#  'Liao, W.',
#  'Loayza, F.',
#  'Loayza, F.R.',
#  'Loayza, K.',
#  'Lopez, A.J.',
#  'Lopez, C.S.',
#  'Lozano, E.',
#  'Lu, Y.',
#  'Lucas, P.',
#  'Lucio, L.E.',
#  'Luong, H.',
#  'Luzardo, G.',
#  'Mac, T.T.',
#  'MacArini, L.A.',
#  'Macarini, L.A.',
#  'Madrid, C.E.',
#  'Marin-Garcia, I.',
#  'Martin, C.A.',
#  'Martinez Vera, C.R.',
#  'Martinez, C.',
#  'Martinez-Maldonado, R.',
#  'Martín, C.A.',
#  'Martínez-Maldonado, R.',
#  'Maya, R.',
#  'Maya, R.D.',
#  'Mckay, T.',
#  'Medina, C.V.',
#  'Mena, L.',
#  'Mendieta, J.',
#  'Mendieta, M.',
#  'Mendoza, L.E.',
#  'Merceron, A.',
#  'Millan, M.E.',
#  'Minh Nguyen, D.',
#  'Miño, M.F.',
#  'Molenaar, I.',
#  'Molina, K.G.',
#  'Molina, M.',
#  'Molinaro, M.',
#  'Monsalve, C.',
#  'Montes, H.',
#  'Montoya, A.',
#  'Mora, H.',
#  'Morales, L.E.M.',
#  'Moreira, A.P.',
#  'Moreira, V.',
#  'Munoz, J.A.',
#  'Munoz-Arcentales, A.',
#  'Munoz-Arcentales, J.A.',
#  'Murillo, J.',
#  'Murillo, J.R.',
#  'Muñoz, L.',
#  'Nandola, N.N.',
#  'Narvaez, R.B.',
#  'Nunes, J.B.C.',
#  'Nunez-Idrovo, L.',
#  'Ocampo, J.',
#  'Ochoa, A.',
#  'Ochoa, D.',
#  'Ochoa, K.',
#  'Ochoa, X.',
#  'Oliveira, M.',
#  'Ordoñez, D.M.',
#  'Orellana Fantoni, C.',
#  'Ortiz, K.',
#  'Ortiz, M.',
#  'Ortiz-Aviles, L.',
#  'Ortiz-Rojas, M.',
#  'Oviatt, S.',
#  'Oviedo, I.D.',
#  'Oyola, A.',
#  'Padilla, V.S.',
#  'Padilla-Lozano, C.',
#  'Pal, J.',
#  'Panchana, F.',
#  'Parrales, J.',
#  'Pelaez, E.',
#  'Peláez, E.',
#  'Peralta, J.A.',
#  'Perez-Jimenez, R.',
#  'Pesantez, J.',
#  'Phatak, S.S.',
#  'Philips, W.',
#  'Pilco, N.',
#  'Pinargote, A.',
#  'Pincay, J.',
#  'Pino, R.',
#  'Pita, O.',
#  'Plaza, D.',
#  'Plaza, D.A.',
#  'Plaza, J.A.',
#  'Ponguillo, R.',
#  'Ponguillo, R.A.',
#  'Poujol, J.',
#  'Power, T.',
#  'Prieto, L.P.',
#  'Puente, S.C.',
#  'Pundir, M.',
#  'Quelal, R.',
#  'Quelal, R.E.',
#  'Quimba, S.',
#  'Quimis, M.',
#  'Quiñonez, Y.',
#  'Rabadan, J.',
#  'Ramirez-Aguilera, A.M.',
#  'Realpe, M.',
#  'Recalde, A.',
#  'Recalde, L.',
#  'Rengifo, J.',
#  'Revelo, H.V.',
#  'Rivadeneira, R.E.',
#  'Rivera, D.E.',
#  'Rodes, V.',
#  'Rodriguez, J.',
#  'Rodriguez, J.S.',
#  'Rodríguez, J.S.',
#  'Rodríguez-Echeverría, J.',
#  'Rodríguez-Triana, M.J.',
#  'Romero, C.',
#  'Romero, D.',
#  'Romero, D.G.',
#  'Romero, J.',
#  'Romero, J.A.',
#  'Rosero, S.',
#  'Rousseaux, S.',
#  'Rugel, G.M.V.',
#  'Sacarelo, C.',
#  'Salazar, C.',
#  'Salazar, D.S.',
#  'Salgado, W.G.',
#  'Salvachua, J.',
#  'Salvachúa, J.',
#  'San Lucas, C.',
#  'San-Lucas, C.',
#  'Sanga, B.R.',
#  'Santos, V.',
#  'Sappa, A.D.',
#  'Schlesinger, A.',
#  'Seipp, K.',
#  'Semanjski, I.',
#  'Sharples, M.',
#  'Shum, S.B.',
#  'Sola-Mora, J.',
#  'Solomon, A.',
#  'Soria, X.',
#  'Spikol, D.',
#  'Suarez, P.L.',
#  'Suárez, P.L.',
#  'Suárez, S.',
#  'Talluri, S.',
#  'Teran, E.',
#  'Ternier, S.',
#  'Timms, K.P.',
#  'Toledo, R.',
#  'Torres, J.',
#  'Totoy, G.',
#  'Touhafi, A.',
#  'Tsiligianni, E.',
#  'Ullón, H.',
#  'Ullón, R.H.',
#  'Vaca, C.',
#  'Vaca, D.',
#  'Vaca-Urbano, F.',
#  'Valarezo, E.',
#  'Valcke, M.',
#  'Valencia, A.J.',
#  'Valle, D.',
#  'Van Coillie, F.',
#  'Van Eyk, E.',
#  'Van Gheluwe, C.',
#  'Vargas, G.',
#  'Vargas, W.V.',
#  'Vela, E.M.',
#  'Velasco, M.',
#  'Velasquez Vargas, W.A.',
#  'Velasquez, W.',
#  'Velásquez, W.',
#  'Vera, C.R.M.',
#  'Verbert, K.',
#  'Vergara, C.',
#  'Veriñaz Jadan, H.I.',
#  'Veriñaz, H.I.',
#  'Villacis, D.M.',
#  'Villalba, R.',
#  'Villavicencio, A.M.',
#  'Villavicencio, J.',
#  'Villavicencio, M.',
#  'Villegas, P.',
#  'Vintimilla, B.',
#  'Vintimilla, B.X.',
#  'Vishwanath, A.',
#  'Viteri, J.A.',
#  'Vlacic, L.',
#  'Vélez, J.',
#  'Walter, J.',
#  'Wang, X.',
#  'Weibel, N.',
#  'Willnecker, F.',
#  'Wong-Villacres, M.',
#  'Wong-Villacrés, M.',
#  'Worsley, M.',
#  'Xie, D.',
#  'Xie, D.-L.',
#  'Xie, Q.',
#  'Yanez, W.',
#  'Yánez-Pazmino, W.',
#  'Zambrano, D.',
#  'Zambrano, O.',
#  'Zhao, Y.',
#  'Zuo, L.',
#  'de la Escalera, A.',
#  'Łuszczak, A.'}

# %%
coau_df2 = coau_df[coau_df["Year"]<2018]
G2 = nx.from_pandas_edgelist(coau_df2,"Source","Target",['Weight','Year'],create_using=nx.Graph())
nodos2 = list(G2.nodes)
nodosNuevos = set(nodos)-set(nodos2)
print(len(nodosNuevos))
# Out:
# 232

# %%
#Obteniendo dataframe de pares de nodos que no tienen coneccion

adj_G = nx.to_numpy_matrix(G, nodelist = nodos)
all_unconnected_pairs = []

offset = 0
for i in range(adj_G.shape[0]):
  for j in range(offset,adj_G.shape[1]):
    if i != j:
        #Para evitar tener demasiados ejemplos de pares de nodos que no tienen coneccion
        #Solo se tomaran solo los ejemplos de los pares de nodos cuya distancia mas corta
        #sea 2, y que no tengan coneccion
        if nx.shortest_path_length(G, str(nodos[i]), str(nodos[j])) ==2:
          if adj_G[i,j] == 0:
            all_unconnected_pairs.append((nodos[i],nodos[j]))

  offset = offset + 1

node_1_unlinked = [i[0] for i in all_unconnected_pairs]
node_2_unlinked = [i[1] for i in all_unconnected_pairs]

#Creando dataframe para almacenar a los pares de nodos no conectados que se recogieron
data = pd.DataFrame({'Source':node_1_unlinked,'Target':node_2_unlinked})
data['Weight'] = 0
data['link'] = 0

indices = range(len(data['Source']))

#Separando el dataframe en datos para train y para test
#(se busca un numero no muy grande de datos de pares que no tienen coneccion en los datos para entrenar, para
#evitar que los datos de entrenamiento esten desbalanceados)

removeIn, noRemoveIn = train_test_split(indices,test_size=0.25,random_state=32)

test= data.copy()
test = test.drop(index=noRemoveIn)

data = data.drop(index=removeIn)

data.shape #Cantidad de ejemplos negativos
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# <ipython-input-14-e66c8788235e> in <module>
#      11         #Solo se tomaran solo los ejemplos de los pares de nodos cuya distancia mas corta
#      12         #sea 2, y que no tengan coneccion
# ---> 13         if nx.shortest_path_length(G, str(nodos[i]), str(nodos[j])) ==2:
#      14           if adj_G[i,j] == 0:
#      15             all_unconnected_pairs.append((nodos[i],nodos[j]))
#
# c:\users\core i7 ultimate\appdata\local\programs\python\python38\lib\site-packages\networkx\algorithms\shortest_paths\generic.py in shortest_path_length(G, source, target, weight, method)
#     310             # Find shortest source-target path.
#     311             if method == 'unweighted':
# --> 312                 p = nx.bidirectional_shortest_path(G, source, target)
#     313                 paths = len(p) - 1
#     314             elif method == 'dijkstra':
#
# c:\users\core i7 ultimate\appdata\local\programs\python\python38\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in bidirectional_shortest_path(G, source, target)
#     224
#     225     # call helper to do the real work
# --> 226     results = _bidirectional_pred_succ(G, source, target)
#     227     pred, succ, w = results
#     228
#
# c:\users\core i7 ultimate\appdata\local\programs\python\python38\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in _bidirectional_pred_succ(G, source, target)
#     292                         return pred, succ, w
#     293
# --> 294     raise nx.NetworkXNoPath("No path between %s and %s." % (source, target))
#     295
#     296
#
# NetworkXNoPath: No path between Santos, V. and Rottondi, C..

# %%
#Trabajando con los pares de nodos que si estan conectados

#Obteniendo lista de los links que se pueden borrar (que no eliminan nodos, o dividen al grafo en mas de una componente) y que
#estan despues del año establecido

year = 2018
initial_node_count = len(G.nodes)

coau_df_temp = coau_df.copy()

omissible_links_index = []
for i in tqdm(coau_df.index.values):
    if G.adj[coau_df.values[i,0]][coau_df.values[i,1]]['Year']>=year:
        # Eliminar una arista y construir un nuevo grafo sin esa unica arista
        G_temp = nx.from_pandas_edgelist(coau_df_temp.drop(index=i), "Source", "Target",["Weight"], create_using=nx.Graph())

        # Verificando que al eliminar este par, no parte el grafo, y que el numero de nodos siga siendo el mismo

        if (nx.number_connected_components(G_temp) == 1) and (len(G_temp.nodes) == initial_node_count):
            omissible_links_index.append(i)
            coau_df_temp = coau_df_temp.drop(i)

#creando dataframe de edges que se pueden remover

coau_df_temp2 = coau_df.copy()
coau_df_temp2["link"]=1

#Separando dataframe en datos para train y test

testlinks = coau_df_temp2.loc[omissible_links_index]
coau_df_temp = coau_df_temp2.drop(index=omissible_links_index)

data = data.append(coau_df_temp[['Source', 'Target', 'link','Weight']], ignore_index=True)
data["Weight"] = data["Weight"].astype('int64')

test = test.append(testlinks[['Source', 'Target', 'link','Weight']], ignore_index=True)
data.shape
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1050/1050 [00:03<00:00, 278.59it/s]
# (4217, 4)

# %%
#Definiendo varias metricas para link prediction

def commonNeighbors(G,source,target):
  adj = dict(G.adj[source])
  adj2 = dict(G.adj[target])
  commonNeighbors = set(adj.keys()) & set(adj2.keys())
  return commonNeighbors

def jaccardCoeff(G,source,target):
  adj = dict(G.adj[source])
  adj2 = dict(G.adj[target])
  unionNeighbors = set(adj.keys()) | set(adj2.keys())
  commonNeighbors = set(adj.keys()) & set(adj2.keys())
  return len(commonNeighbors)/len(unionNeighbors)

def adamicAdar(G,source,target):
  cn = commonNeighbors(G,source,target)
  coeff = 0
  for neighbor in cn:
    coeff += 1/np.log(len(dict(G.adj[neighbor]).keys()))
  return coeff

# %%
#Creando nuevo grafo sin los links eliminados aleatoriamente
G_data = nx.from_pandas_edgelist(coau_df_temp, "Source", "Target",["Weight"], create_using=nx.Graph())

# %%
#Obteniendo las features, y armando los arrays para usarlo en la regresion logistica

Xtrain =[]
Ytrain =[]
for i in data.values:
  Xtrain.append([adamicAdar(G_data,i[0],i[1])])
  Ytrain.append(i[3])

Xtest = []
Ytest = []
for i in test.values:
  Xtest.append([adamicAdar(G_data,i[0],i[1])])
  Ytest.append(i[3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-7133a1d5a6bc> in <module>
#       4 Ytrain =[]
#       5 for i in data.values:
# ----> 6   Xtrain.append([adamicAdar(G_data,i[0],i[1])])
#       7   Ytrain.append(i[3])
#       8
#
# <ipython-input-5-749f96a771ad> in adamicAdar(G, source, target)
#      15
#      16 def adamicAdar(G,source,target):
# ---> 17   cn = commonNeighbors(G,source,target)
#      18   coeff = 0
#      19   for neighbor in cn:
#
# <ipython-input-5-749f96a771ad> in commonNeighbors(G, source, target)
#       3 def commonNeighbors(G,source,target):
#       4   adj = dict(G.adj[source])
# ----> 5   adj2 = dict(G.adj[target])
#       6   commonNeighbors = set(adj.keys()) & set(adj2.keys())
#       7   return commonNeighbors
#
# c:\users\core i7 ultimate\appdata\local\programs\python\python38\lib\site-packages\networkx\classes\coreviews.py in __getitem__(self, name)
#      79
#      80     def __getitem__(self, name):
# ---> 81         return AtlasView(self._atlas[name])
#      82
#      83     def copy(self):
#
# KeyError: 'Lim, G.H.'

# %%
lr = LogisticRegression(class_weight="balanced")

lr.fit(Xtrain, Ytrain)

predictions = lr.predict(Xtest)
print("Regresion logistica",roc_auc_score(Ytest, predictions))
# Out:
# Regresion logistica 0.6348194810691148

# %%
# Accuracy de varios tipos de aciertos 

aciertosTotales = 0
unosAcertados = 0
cerosAcertados = 0

for tst, y in zip(Xtest,Ytest):
    
    predic = lr.predict([tst])[0]    
    if y == predic:
        aciertosTotales+=1
        
    if y == 1 and predic == 1:
        unosAcertados+=1
      
    if y == 0 and predic ==0:
        cerosAcertados+=1

acc = aciertosTotales/len(Ytest)
print("Aciertos totales:",acc)

acc2 = unosAcertados/sum(Ytest)
print("unos acertados:",acc2)

acc3 = cerosAcertados/(len(Ytest)-sum(Ytest))
print("ceros acertados:",acc3)
# Out:
# Aciertos totales: 0.8730891260455725
# unos acertados: 0.3888888888888889
# ceros acertados: 0.8807500732493407
